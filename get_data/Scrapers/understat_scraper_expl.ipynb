# %%
import requests
from bs4 import BeautifulSoup as bs
import os
import pandas as pd
import json

# %%
url = 'https://understat.com/player/'

# %%
page = requests.get(url + '/5835')
print(page.status_code)
# Out:
# 404

# %%
soup = bs(page.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <base href="https://understat.com/"/>
# <title>Arturo Lupoli |  | xG | Shot Map | Goal stats | Understat.com</title>
# <meta charset="utf-8"/>
# <meta content="Arturo Lupoli football stats. xG, shot map, match history. Minutes, goals and assits by club, position, situation." name="description"/>
# <meta content="Arturo Lupoli, xG, expected goals, shot map, goals, assists, advanced statistics, match history, football stats" name="Keywords"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="understat" name="apple-mobile-web-app-title"/>
# <meta content="understat" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="0" http-equiv="expires"/>
# <link href="css/main.css?v=2.8" media="screen" rel="stylesheet"/>
# </head>
# <body class="theme-dark">
# <script>
# 			var THEME = localStorage.getItem("theme") || 'DARK';
# 			document.body.className = "theme-" + THEME.toLowerCase();
# 		</script>
# <div class="wrapper">
# <header class="clearfix" id="header">
# <div class="header-wrapper">
# 				Arturo Lupoli
# 				<nav class="m-navigation-main">
# <ul class="h-inner">
# <li class="player-search">
# <input class="typeahead" placeholder="Find player by name" type="search"/>
# <span class="icon"><i class="fa fa-search"></i></span>
# </li>
# <li>
# <a class="link-icon" href="" title="Main page">
# <i aria-hidden="true" class="fas fa-home"></i>
# </a>
# </li>
# <li>
# <a class="link-icon" href="office" title="Personal cabinet">
# <i aria-hidden="true" class="fas fa-sign-in-alt"></i>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <div class="preloader">
# <div class="preloader-container">
# <div class="circ1"><div></div></div>
# <div class="circ2"><div></div></div>
# <div class="circ3"><div></div></div>
# <div class="circ4"><div></div></div>
# </div>
# </div>
# <div class="preloader table-preloader is-hide" id="table-preloader">
# <div class="preloader-container">
# <div class="circ1"><div></div></div>
# <div class="circ2"><div></div></div>
# <div class="circ3"><div></div></div>
# <div class="circ4"><div></div></div>
# </div>
# </div>
# <input checked="" id="themes-switch" name="themes-switch" type="checkbox"/>
# <label for="themes-switch" title="Change theme"></label>
# <div class="page-wrapper">
# <div class="promotion">
# <ins class="adsbygoogle" data-ad-client="ca-pub-7470116180195095" data-ad-format="auto" data-ad-slot="2199699885" data-full-width-responsive="true" style="display:block"></ins>
# </div>
# <ul class="breadcrumb">
# <li><a href="https://understat.com/">Home</a></li>
# <li><a href="league//"></a></li>
# <li><a href="team//"></a></li>
# <li>Arturo Lupoli</li>
# </ul>
# <div class="block">
# <div class="block-content">
# <div class="alert">Player data not found</div>
# <script>
# 	var groupsData 		= JSON.parse('\x7B\x22season\x22\x3A\x5B\x5D,\x22position\x22\x3A\x5B\x5D,\x22situation\x22\x3A\x5B\x5D,\x22shotZones\x22\x3A\x5B\x5D,\x22shotTypes\x22\x3A\x5B\x5D\x7D'),
# 		avgPlayerStats 	= JSON.parse('null');
# </script> </div>
# </div>
# <div class="block">
# <div class="alert">Player data not found</div>
# <script>
# 	var minMaxPlayerStats 	= JSON.parse('\x5B\x5D'),
# 		positionsList		= JSON.parse('\x5B\x22GK\x22,\x22DR\x22,\x22DC\x22,\x22DL\x22,\x22DMR\x22,\x22DML\x22,\x22DMC\x22,\x22MR\x22,\x22MC\x22,\x22ML\x22,\x22AMR\x22,\x22AMC\x22,\x22AML\x22,\x22FWR\x22,\x22FW\x22,\x22FWL\x22,\x22Sub\x22\x5D');
# </script></div>
# <div class="block block-w9">
# <div class="block-content">
# <div class="filters filters-shots">
# <div class="filter">
# <label class="filter-title">Season</label>
# <select multiple="" name="scheme-season" placeholder="All">
# </select>
# </div>
# <div class="filter">
# <label class="filter-title">Situation</label>
# <select multiple="" name="scheme-situation" placeholder="All">
# <option value=""></option>
# <option value="DirectFreekick">Direct Freekick</option>
# <option value="FromCorner">From corner</option>
# <option value="OpenPlay">Open play</option>
# <option value="Penalty">Penalty</option>
# <option value="SetPiece">Set piece</option>
# </select>
# </div>
# <div class="filter">
# <label class="filter-title">Result</label>
# <select multiple="" name="scheme-result" placeholder="All">
# <option value="Goal">Goal</option>
# <option value="ShotOnPost">Shot on post</option>
# <option value="SavedShot">Saved shot</option>
# <option value="BlockedShot">Blocked shot</option>
# <option value="MissedShots">Missed shot</option>
# </select>
# </div>
# </div>
# <div class="scheme-block" data-scheme="shotMap">
# <canvas id="shotMap"></canvas>
# <button class="shotsHintButton"></button>
# <div class="shotsHint is-hide">
# <div class="shotsRadius"></div>
# <div class="shotsColor"></div>
# </div>
# <div id="note" style="display:none;"></div>
# </div>
# <script>
# 	var shotsData 	= JSON.parse('\x5B\x5D'),
# 		player_info	= JSON.parse('\x7B\x22id\x22\x3A\x225834\x22,\x22name\x22\x3A\x22Arturo\x20Lupoli\x22,\x22fid\x22\x3A\x22294160\x22\x7D');
# </script> </div>
# </div>
# <div class="block">
# <div class="block-content">
# <div class="alert">History data not found</div>
# <script>
# 	var matchesData	= JSON.parse('\x5B\x5D');
# </script> </div>
# </div>
# </div>
# <div class="overlay is-hide"></div>
# <div class="modal is-hide">
# <div class="modal-header">
# <div class="modal-title"></div>
# <span class="modal-close"></span>
# </div>
# <div class="modal-body"></div>
# </div>
# <div class="grass-container">
# <div class="grass"></div>
# <div class="grass"></div>
# </div>
# <footer id="footer">
# <div class="footer-wrapper">
# <ul>
# <li><a href="league/EPL">EPL</a></li>
# <li><a href="league/La_liga">La liga</a></li>
# <li><a href="league/Bundesliga">Bundesliga</a></li>
# <li><a href="league/Serie_A">Serie A</a></li>
# <li><a href="league/Ligue_1">Ligue 1</a></li>
# <li><a href="league/RFPL">RFPL</a></li>
# </ul>
# <div><a href="mailto:support@understat.com">support@understat.com</a></div>
# <div>© understat 2017</div>
# </div>
# </footer>
# </div>
# <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>
# <script>
# 		WebFont.load({
# 			google: {
# 				families: ['Barlow:500', 'Anton']
# 			},
# 			active: function(){
# 				flagFontsLoading = true;
# 			}
# 		});
# 		var BASE_URL = 'https://understat.com/',
# 			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224356\x22\x7D') ;
# 	</script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>
# <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>
# <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>
# <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>
# <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>
# <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>
# <script>
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 		ga('create', 'UA-101482034-1', 'auto');
# 		ga('send', 'pageview');
#
# 					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
# 			</script>
# <script defer="" src="js/player.js?v=2.5" type="text/javascript"></script>
# </body>
# </html>

# %%
bad_script = soup.find_all('script')
print(bad_script)
string = bad_script[1].string
# Out:
# [<script>
# 			var THEME = localStorage.getItem("theme") || 'DARK';
# 			document.body.className = "theme-" + THEME.toLowerCase();
# 		</script>, <script>
# 	var groupsData 		= JSON.parse('\x7B\x22season\x22\x3A\x5B\x5D,\x22position\x22\x3A\x5B\x5D,\x22situation\x22\x3A\x5B\x5D,\x22shotZones\x22\x3A\x5B\x5D,\x22shotTypes\x22\x3A\x5B\x5D\x7D'),
# 		avgPlayerStats 	= JSON.parse('null');
# </script>, <script>
# 	var minMaxPlayerStats 	= JSON.parse('\x5B\x5D'),
# 		positionsList		= JSON.parse('\x5B\x22GK\x22,\x22DR\x22,\x22DC\x22,\x22DL\x22,\x22DMR\x22,\x22DML\x22,\x22DMC\x22,\x22MR\x22,\x22MC\x22,\x22ML\x22,\x22AMR\x22,\x22AMC\x22,\x22AML\x22,\x22FWR\x22,\x22FW\x22,\x22FWL\x22,\x22Sub\x22\x5D');
# </script>, <script>
# 	var shotsData 	= JSON.parse('\x5B\x5D'),
# 		player_info	= JSON.parse('\x7B\x22id\x22\x3A\x225834\x22,\x22name\x22\x3A\x22Arturo\x20Lupoli\x22,\x22fid\x22\x3A\x22294160\x22\x7D');
# </script>, <script>
# 	var matchesData	= JSON.parse('\x5B\x5D');
# </script>, <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>, <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>, <script>
# 		WebFont.load({
# 			google: {
# 				families: ['Barlow:500', 'Anton']
# 			},
# 			active: function(){
# 				flagFontsLoading = true;
# 			}
# 		});
# 		var BASE_URL = 'https://understat.com/',
# 			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224356\x22\x7D') ;
# 	</script>, <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>, <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>, <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>, <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>, <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>, <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>, <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>, <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>, <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>, <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>, <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>, <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>, <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>, <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>, <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>, <script>
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 		ga('create', 'UA-101482034-1', 'auto');
# 		ga('send', 'pageview');
#
# 					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
# 			</script>, <script defer="" src="js/player.js?v=2.5" type="text/javascript"></script>]

# %%
ind_start = string.index("('")+2
ind_end = string.index("')")
json_data = string[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

data = json.loads(json_data)
data = data['season']
data
# Out:
# []

# %%
columns = ['position',
            'games',
            'goals',
            'shots',
            'time',
            'xG',
            'assists',
            'xA',
            'key_passes',
            'season',
            'team',
            'yellow',
            'red',
            'npg',
            'npxG',
            'xGChain',
            'xGBuildup']
column_data = dict()
for c in columns:
    column_data[c]=[]

# %%
for d in data:
    for c in columns:
        print(type(d[c]))
        column_data[c].append(d[c])

print(column_data)
# Out:
# {'position': [], 'games': [], 'goals': [], 'shots': [], 'time': [], 'xG': [], 'assists': [], 'xA': [], 'key_passes': [], 'season': [], 'team': [], 'yellow': [], 'red': [], 'npg': [], 'npxG': [], 'xGChain': [], 'xGBuildup': []}

# %%
df = pd.DataFrame(column_data)
df
# Out:
# Empty DataFrame
# Columns: [position, games, goals, shots, time, xG, assists, xA, key_passes, season, team, yellow, red, npg, npxG, xGChain, xGBuildup]
# Index: []

# %%
soup
soup_name = soup.find_all('meta',)
content = soup_name[2]['content']
content = content.split(',',1)[0]
print(content)
# Out:
# Arturo Lupoli

# %%
url_league = 'https://understat.com/league/'
'team/year'
page_league = requests.get(url_league + '/Ligue_1' + '/2016')

soup_league = bs(page_league.text,'html.parser')

soup_league
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <base href="https://understat.com/"/>
# <title>Ligue 1 xG Table and Scorers for the 2016/2017 season | Understat.com</title>
# <meta charset="utf-8"/>
# <meta content="xG table of Ligue 1 standings and top scorers for the 2016/2017 season, also tables from past seasons and other European football leagues." name="description"/>
# <meta content="Ligue 1, xg table,scorers, expected goals table, season 2016/2017" name="Keywords"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="understat" name="apple-mobile-web-app-title"/>
# <meta content="understat" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="0" http-equiv="expires"/>
# <link href="css/main.css?v=2.8" media="screen" rel="stylesheet"/>
# </head>
# <body class="theme-dark">
# <script>
# 			var THEME = localStorage.getItem("theme") || 'DARK';
# 			document.body.className = "theme-" + THEME.toLowerCase();
# 		</script>
# <div class="wrapper">
# <header class="clearfix" id="header">
# <div class="header-wrapper">
# <select data-height="400" data-search="true" name="league">
# <option value="EPL">EPL</option>
# <option value="La liga">La liga</option>
# <option value="Bundesliga">Bundesliga</option>
# <option value="Serie A">Serie A</option>
# <option selected="" value="Ligue 1">Ligue 1</option>
# <option value="RFPL">RFPL</option>
# </select>
# <select data-redirect="league" name="season">
# <option value="2024">2024/2025</option>
# <option value="2023">2023/2024</option>
# <option value="2022">2022/2023</option>
# <option value="2021">2021/2022</option>
# <option value="2020">2020/2021</option>
# <option value="2019">2019/2020</option>
# <option value="2018">2018/2019</option>
# <option value="2017">2017/2018</option>
# <option selected="" value="2016">2016/2017</option>
# <option value="2015">2015/2016</option>
# <option value="2014">2014/2015</option>
# </select>
# <nav class="m-navigation-main">
# <ul class="h-inner">
# <li class="player-search">
# <input class="typeahead" placeholder="Find player by name" type="search"/>
# <span class="icon"><i class="fa fa-search"></i></span>
# </li>
# <li>
# <a class="link-icon" href="" title="Main page">
# <i aria-hidden="true" class="fas fa-home"></i>
# </a>
# </li>
# <li>
# <a class="link-icon" href="office" title="Personal cabinet">
# <i aria-hidden="true" class="fas fa-sign-in-alt"></i>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <div class="preloader">
# <div class="preloader-container">
# <div class="circ1"><div></div></div>
# <div class="circ2"><div></div></div>
# <div class="circ3"><div></div></div>
# <div class="circ4"><div></div></div>
# </div>
# </div>
# <div class="preloader table-preloader is-hide" id="table-preloader">
# <div class="preloader-container">
# <div class="circ1"><div></div></div>
# <div class="circ2"><div></div></div>
# <div class="circ3"><div></div></div>
# <div class="circ4"><div></div></div>
# </div>
# </div>
# <input checked="" id="themes-switch" name="themes-switch" type="checkbox"/>
# <label for="themes-switch" title="Change theme"></label>
# <div class="page-wrapper">
# <div class="promotion">
# <ins class="adsbygoogle" data-ad-client="ca-pub-7470116180195095" data-ad-format="auto" data-ad-slot="2199699885" data-full-width-responsive="true" style="display:block"></ins>
# </div>
# <ul class="breadcrumb">
# <li><a href="https://understat.com/">Home</a></li>
# <li>Ligue 1</li>
# </ul>
# <div class="block">
# <div class="block-content">
# <div class="calendar">
# <button class="calendar-prev" data-type="week">prev week</button>
# <button class="calendar-next" data-type="week">next week</button>
# <div class="filters filter-timezone">
# <div class="filter">
# <label class="filter-title">Set time zone</label>
# <input id="timezone-on" name="timezone" type="radio" value="on">
# <label for="timezone-on">On</label>
# <input id="timezone-off" name="timezone" type="radio" value="off"/>
# <label for="timezone-off">Off</label>
# </input></div>
# </div>
# <div class="calendar-container"></div>
# </div>
# <script>
# 	var datesData 	= JSON.parse('\x5B\x7B\x22id\x22\x3A\x222249\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22162\x22,\x22title\x22\x3A\x22SC\x20Bastia\x22,\x22short_title\x22\x3A\x22BAS\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22161\x22,\x22title\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22short_title\x22\x3A\x22PSG\x22\x7D,\x22goals\x22\x3A\x7B\x22h\x22\x3A\x220\x22,\x22a\x22\x3A\x221\x22\x7D,\x22xG\x22\x3A\x7B\x22h\x22\x3A\x220.828385\x22,\x22a\x22\x3A\x220.664887\x22\x7D,\x22datetime\x22\x3A\x222016\x2D08\x2D12\x2022\x3A00\x3A00\x22,\x22forecast\x22\x3A\x7B\x22w\x22\x3A\x220.3629\x22,\x22d\x22\x3A\x220.3789\x22,\x22l\x22\x3A\x220.2582\x22\x7D\x7D,\x7B\x22id\x22\x3A\x222250\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22171\x22,\x22title\x22\x3A\x22Monaco\x22,\x22short_title\x22\x3A\x22MON\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22169\x22,\x22title\x22\x3A\x22Guingamp\x22,\x22short_title\x22\x3A\x22GUI\x22\x7D,\x22goals\x22\x3A\x7B\x22h\x22\x3A\x222\x22,\x22a\x22\x3A\x222\x22\x7D,\x22xG\x22\x3A\x7B\x22h\x22\x3A\x222.49641\x22,\x22a\x22\x3A\x220.699022\x22\x7D,\x22datetime\x22\x3A\x222016\x2D08\x2D12\x2022\x3A30\x3A00\x22,\x22forecast\x22\x3A\x7B\x22w\x22\x3A\x220.831\x22,\x22d\x22\x3A\x220.1269\x22,\x22l\x22\x3A\x220.0421\x22\x7D\x7D,\x7B\x22id\x22\x3A\x222251\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22176\x22,\x22title\x22\x3A\x22Bordeaux\x22,\x22short_title\x22\x3A\x22BOR\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22175\x22,\x22title\x22\x3A\x22Saint\x2DEtienne\x22,\x22short_title\x22\x3A\x22SEN\x22\x7D,\x22goals\x22\x3A\x7B\x22h\x22\x3A\x223\x22,\x22a\x22\x3A\x222\x22\x7D,\x22xG\x22\x3A\x7B\x22h\x22\x3A\x221.16592\x22,\x22a\x22\x3A\x221.50131\x22\x7D,\x22datetime\x22\x3A\x222016\x2D08\x2D13\x2019\x3A00\x3A00\x22,\x22forecast\x22\x3A\x7B\x22w\x22\x3A\x220.2683\x22,\x22d\x22\x3A\x220.2894\x22,\x22l\x22\x3A\x220.4423\x22\x7D\x7D,\x7B\x22id\x22\x3A\x222252\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22166\x22,\x22title\x22\x3A\x22Montpellier\x22,\x22short_title\x22\x3A\x22MPL\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22167\x22,\x22title\x22\x3A\x22Angers\x22,\x22short_title\x22\x3A\x22ANG\x22\x7D,\x22goals\x22\x3A\x7B\x22h\x22\x3A\x221\x22,\x22a\x22\x3A\x220\x22\x7D,\x22xG\x22\x3A\x7B\x22h\x22\x3A\x220.879179\x22,\x22a\x22\x3A\x220.49342\x22\x7D,\x22datetime\x22\x3A\x222016\x2D08\x2D13\x2022\x3A00\x3A00\x22,\x22forecast\x22\x3A\x7B\x22w\x22\x3A\x220.4457\x22,\x22d\x22\x3A\x220.3675\x22,\x22l\x22\x3A\x220.1868\x22\x7D\x7D,\x7B\x22id\x22\x3A\x222253\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22165\x22,\x22title\x22\x3A\x22Caen\x22,\x22short_title\x22\x3A\x22CAE\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22179\x22,\x22title\x22\x3A\x22Lorient\x22,\x22short_title\x22\x3A\x22LOR\x22\x7D,\x22goals\x22\x3A\x7B\x22h\x22\x3A\x223\x22,\x22a\x22\x3A\x222\x22\x7D,\x22xG\x22\x3A\x7B\x22h\x22\x3A\x222.27284\x22,\x22a\x22\x3A\x221.9864\x22\x7D,\x22datetime\x22\x3A\x222016\x2D08\x2D13\x2022\x3A00\x3A00\x22,\x22forecast\x22\x3A\x7B\x22w\x22\x3A\x220.4333\x22,\x22d\x22\x3A\x220.2611\x22,\x22l\x22\x3A\x220.3056\x22\x7D\x7D,\x7B\x22id\x22\x3A\x222254\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22180\x22,\x22title\x22\x3A\x22Metz\x22,\x22short_title\x22\x3A\x22MET\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22160\x22,\x22title\x22\x3A\x22Lille\x22,\x22short_title\x22\x3A\x22LIL\x22\x7D,\x22goals\x22\x3A\x7B\x22h\x22\x3A\x223\x22,\x22a\x22\x3A\x222\x22\x7D,\x22xG\x22\x3A\x7B\x22h\x22\x3A\x222.31706\x22,\x22a\x22\x3A\x221.87778\x22\x7D,\x22datetime\x22\x3A\x222016\x2D08\x2D13\x2022\x3A00\x3A00\x22,\x22forecast\x22\x3A\x7B\x22w\x22\x3A\x220.4874\x22,\x22d\x22\x3A\x220.2684\x22,\x22l\x22\x3A\x220.2442\x22\x7D\x7D,\x7B\x22id\x22\x3A\x222255\x22,\x22isResult\x22\x3Atrue,\x22h\x22\x3A\x7B\x22id\x22\x3A\x22181\x22,\x22title\x22\x3A\x22Dijon\x22,\x22short_title\x22\x3A\x22DJN\x22\x7D,\x22a\x22\x3A\x7B\x22id\x22\x3A\x22168\x22,\x22title\x22\x3A\x22Nantes\ ...
# 		_week		= 39,
# 		_year		= 2024;
# </script> </div>
# </div>
# <div class="block">
# <div class="block-content">
# <div class="filters">
# <div class="filter">
# <input checked="" id="scheme1" name="scheme" type="radio" value="chemp"/>
# <label for="scheme1">Table</label>
# <input id="scheme2" name="scheme" type="radio" value="chart"/>
# <label for="scheme2">Charts</label>
# </div>
# <div class="filter">
# <input checked="" id="home-away1" name="home-away" type="radio" value="t"/>
# <label for="home-away1">overall</label>
# <input id="home-away2" name="home-away" type="radio" value="h"/>
# <label for="home-away2">home</label>
# <input id="home-away3" name="home-away" type="radio" value="a"/>
# <label for="home-away3">away</label>
# </div>
# <div class="filter is-hide">
# <label class="filter-title">parameter</label>
# <select data-height="200" name="chart-type">
# <option value="wins">W</option>
# <option value="draws">D</option>
# <option value="loses">L</option>
# <option value="scored">G</option>
# <option value="missed">GA</option>
# <option selected="" value="pts">PTS</option>
# <option value="xG">xG</option>
# <option value="npxG">NPxG</option>
# <option value="xGA">xGA</option>
# <option value="npxGA">NPxGA</option>
# <option value="npxGD">NPxGD</option>
# <option value="ppda">PPDA</option>
# <option value="ppda_allowed">OPPDA</option>
# <option value="deep">DC</option>
# <option value="deep_allowed">ODC</option>
# <option value="xpts">xPTS</option>
# </select>
# </div>
# <input autocomplete="off" class="datepicker" name="date-start" placeholder="Start date" type="text" value=""/>
# <span class="datepicker-icon"></span>
# <input autocomplete="off" class="datepicker" name="date-end" placeholder="End date" type="text" value=""/>
# <span class="datepicker-icon"></span>
# </div>
# <div class="scheme-block" data-scheme="chemp">
# <div class="chemp margin-top" id="league-chemp"></div>
# </div>
# <div class="scheme-block is-hide" data-scheme="chart">
# <canvas id="chart"></canvas>
# <div id="chartLegend"></div>
# </div>
# <script>
# 	var teamsData = JSON.parse('\x7B\x22160\x22\x3A\x7B\x22id\x22\x3A\x22160\x22,\x22title\x22\x3A\x22Lille\x22,\x22history\x22\x3A\x5B\x7B\x22h_a\x22\x3A\x22a\x22,\x22xG\x22\x3A1.877780000000000004689582056016661226749420166015625,\x22xGA\x22\x3A2.317060000000000119513288154848851263523101806640625,\x22npxG\x22\x3A1.877780000000000004689582056016661226749420166015625,\x22npxGA\x22\x3A0.796872000000000024755308913881890475749969482421875,\x22ppda\x22\x3A\x7B\x22att\x22\x3A213,\x22def\x22\x3A14\x7D,\x22ppda_allowed\x22\x3A\x7B\x22att\x22\x3A315,\x22def\x22\x3A27\x7D,\x22deep\x22\x3A4,\x22deep_allowed\x22\x3A4,\x22scored\x22\x3A2,\x22missed\x22\x3A3,\x22xpts\x22\x3A1.0010000000000001119104808822157792747020721435546875,\x22result\x22\x3A\x22l\x22,\x22date\x22\x3A\x222016\x2D08\x2D13\x2022\x3A00\x3A00\x22,\x22wins\x22\x3A0,\x22draws\x22\x3A0,\x22loses\x22\x3A1,\x22pts\x22\x3A0,\x22npxGD\x22\x3A1.08090799999999997993427314213477075099945068359375\x7D,\x7B\x22h_a\x22\x3A\x22h\x22,\x22xG\x22\x3A0.8776990000000000069491079557337798178195953369140625,\x22xGA\x22\x3A0.52490199999999997970689946669153869152069091796875,\x22npxG\x22\x3A0.8776990000000000069491079557337798178195953369140625,\x22npxGA\x22\x3A0.52490199999999997970689946669153869152069091796875,\x22ppda\x22\x3A\x7B\x22att\x22\x3A274,\x22def\x22\x3A27\x7D,\x22ppda_allowed\x22\x3A\x7B\x22att\x22\x3A333,\x22def\x22\x3A33\x7D,\x22deep\x22\x3A9,\x22deep_allowed\x22\x3A4,\x22scored\x22\x3A1,\x22missed\x22\x3A0,\x22xpts\x22\x3A1.6559000000000001495692458775010891258716583251953125,\x22result\x22\x3A\x22w\x22,\x22date\x22\x3A\x222016\x2D08\x2D20\x2022\x3A00\x3A00\x22,\x22wins\x22\x3A1,\x22draws\x22\x3A0,\x22loses\x22\x3A0,\x22pts\x22\x3A3,\x22npxGD\x22\x3A0.3527970000000000272422084890422411262989044189453125\x7D,\x7B\x22h_a\x22\x3A\x22a\x22,\x22xG\x22\x3A0.415974000000000010413003792564268223941326141357421875,\x22xGA\x22\x3A1.7220999999999999641175918441149406135082244873046875,\x22npxG\x22\x3A0.415974000000000010413003792564268223941326141357421875,\x22npxGA\x22\x3A1.7220999999999999641175918441149406135082244873046875,\x22ppda\x22\x3A\x7B\x22att\x22\x3A362,\x22def\x22\x3A34\x7D,\x22ppda_allowed\x22\x3A\x7B\x22att\x22\x3A285,\x22def\x22\x3A23\x7D,\x22deep\x22\x3A4,\x22deep_allowed\x22\x3A5,\x22scored\x22\x3A1,\x22missed\x22\x3A1,\x22xpts\x22\x3A0.37360000000000004316547119742608629167079925537109375,\x22result\x22\x3A\x22d\x22,\x22date\x22\x3A\x222016\x2D08\x2D27\x2022\x3A00\x3A00\x22,\x22wins\x22\x3A0,\x22draws\x22\x3A1,\x22loses\x22\x3A0,\x22pts\x22\x3A1,\x22npxGD\x22\x3A\x2D1.30612599999999989819343682029284536838531494140625\x7D,\x7B\x22h_a\x22\x3A\x22h\x22,\x22xG\x22\x3A0.67898000000000002795985665215994231402873992919921875,\x22xGA\x22\x3A1.4876400000000000733990646040183492004871368408203125,\x22npxG\x22\x3A0.67898000000000002795985665215994231402873992919921875,\x22npxGA\x22\x3A1.4876400000000000733990646040183492004871368408203125,\x22ppda\x22\x3A\x7B\x22att\x22\x3A265,\x22def\x22\x3A33\x7D,\x22ppda_allowed\x22\x3A\x7B\x22att\x22\x3A295,\x22def\x22\x3A27\x7D,\x22deep\x22\x3A1,\x22deep_allowed\x22\x3A2,\x22scored\x22\x3A1,\x22missed\x22\x3A4,\x22xpts\x22\x3A0.64439999999999997282174035717616789042949676513671875,\x22result\x22\x3A\x22l\x22,\x22date\x22\x3A\x222016\x2D09\x2D10\x2022\x3A00\x3A00\x22,\x22wins\x22\x3A0,\x22draws\x22\x3A0,\x22loses\x22\x3A1,\x22pts\x22\x3A0,\x22npxGD\x22\x3A\x2D0.80866000000000004543920795185840688645839691162109375\x7D,\x7B\x22h_a\x22\x3A\x22a\x22,\x22xG\x22\x3A0.52110000000000000763833440942107699811458587646484375,\x22xGA\x22\x3A1.290480000000000071480599217466078698635101318359375,\x22npxG\x22\x3A0.52110000000000000763833440942107699811458587646484375,\x22npxGA\x22\x3A0.530383000000000048856918510864488780498504638671875,\x22ppda\x22\x3A\x7B\x22att\x22\x3A210,\x22def\x22\x3A25\x7D,\x22ppda_allowed\x22\x3A\x7B\x22att\x22\x3A436,\x22def\x22\x3A22\x7D,\x22deep\x22\x3A3,\x22deep_allowed\x22\x3A3,\x22scored\x22\x3A0,\x22missed\x22\x3A1,\x22xpts\x ...
# </script> </div>
# </div>
# <div class="block">
# <div class="block-content">
# <div class="filters">
# <div class="filter">
# <label class="filter-title">Positions</label>
# <select data-height="300" multiple="" name="players-positions" placeholder="All">
# <option value="GK">GK</option>
# <option value="D">D</option>
# <option value="M">M</option>
# <option value="F">F</option>
# <option value="S">S</option>
# </select>
# </div>
# <!--
# 	<div class="filter">
# 		<label class="filter-title">N matches</label>
# 		<input type="number" name="players-n-last-matches" value="" autocomplete="off">
# 	</div>
# 	-->
# <div class="filter">
# <label class="filter-title">Last</label>
# <select name="players-n-last-matches">
# <option value="All">All games</option>
# <option value="3">3 games</option>
# <option value="5">5 games</option>
# <option value="10">10 games</option>
# </select>
# </div>
# <input autocomplete="off" class="datepicker" name="players-date-start" placeholder="Start date" type="text" value=""/>
# <span class="datepicker-icon"></span>
# <input autocomplete="off" class="datepicker" name="players-date-end" placeholder="End date" type="text" value=""/>
# <span class="datepicker-icon"></span>
# <button id="players-filter"><i aria-hidden="true" class="fa fa-filter"></i></button>
# </div>
# <div class="players margin-top" data-countinpage="10" data-pagination="true" id="league-players"></div>
# <script>
# 	var playersData	= JSON.parse('\x5B\x7B\x22id\x22\x3A\x223294\x22,\x22player_name\x22\x3A\x22Edinson\x20Cavani\x22,\x22games\x22\x3A\x2236\x22,\x22time\x22\x3A\x222983\x22,\x22goals\x22\x3A\x2235\x22,\x22xG\x22\x3A\x2236.86661798879504\x22,\x22assists\x22\x3A\x224\x22,\x22xA\x22\x3A\x222.2004457861185074\x22,\x22shots\x22\x3A\x22143\x22,\x22key_passes\x22\x3A\x2225\x22,\x22yellow_cards\x22\x3A\x225\x22,\x22red_cards\x22\x3A\x220\x22,\x22position\x22\x3A\x22F\x20S\x22,\x22team_title\x22\x3A\x22Paris\x20Saint\x20Germain\x22,\x22npg\x22\x3A\x2228\x22,\x22npxG\x22\x3A\x2230.785857636481524\x22,\x22xGChain\x22\x3A\x2230.9136044383049\x22,\x22xGBuildup\x22\x3A\x222.781270120292902\x22\x7D,\x7B\x22id\x22\x3A\x223277\x22,\x22player_name\x22\x3A\x22Alexandre\x20Lacazette\x22,\x22games\x22\x3A\x2230\x22,\x22time\x22\x3A\x222416\x22,\x22goals\x22\x3A\x2228\x22,\x22xG\x22\x3A\x2222.47401910275221\x22,\x22assists\x22\x3A\x223\x22,\x22xA\x22\x3A\x226.658300872892141\x22,\x22shots\x22\x3A\x2285\x22,\x22key_passes\x22\x3A\x2250\x22,\x22yellow_cards\x22\x3A\x223\x22,\x22red_cards\x22\x3A\x220\x22,\x22position\x22\x3A\x22F\x20S\x22,\x22team_title\x22\x3A\x22Lyon\x22,\x22npg\x22\x3A\x2218\x22,\x22npxG\x22\x3A\x2213.352955881506205\x22,\x22xGChain\x22\x3A\x2223.215866085141897\x22,\x22xGBuildup\x22\x3A\x227.629051171243191\x22\x7D,\x7B\x22id\x22\x3A\x22696\x22,\x22player_name\x22\x3A\x22Falcao\x22,\x22games\x22\x3A\x2229\x22,\x22time\x22\x3A\x221969\x22,\x22goals\x22\x3A\x2221\x22,\x22xG\x22\x3A\x2214.863331604748964\x22,\x22assists\x22\x3A\x225\x22,\x22xA\x22\x3A\x222.8996158242225647\x22,\x22shots\x22\x3A\x2280\x22,\x22key_passes\x22\x3A\x2223\x22,\x22yellow_cards\x22\x3A\x222\x22,\x22red_cards\x22\x3A\x220\x22,\x22position\x22\x3A\x22F\x20S\x22,\x22team_title\x22\x3A\x22Monaco\x22,\x22npg\x22\x3A\x2217\x22,\x22npxG\x22\x3A\x2211.822962630540133\x22,\x22xGChain\x22\x3A\x2215.487091083079576\x22,\x22xGBuildup\x22\x3A\x223.574448049068451\x22\x7D,\x7B\x22id\x22\x3A\x22717\x22,\x22player_name\x22\x3A\x22Baf\x5Cu00e9timbi\x20Gomis\x22,\x22games\x22\x3A\x2231\x22,\x22time\x22\x3A\x222613\x22,\x22goals\x22\x3A\x2220\x22,\x22xG\x22\x3A\x2218.49983580969274\x22,\x22assists\x22\x3A\x223\x22,\x22xA\x22\x3A\x222.79583902284503\x22,\x22shots\x22\x3A\x2291\x22,\x22key_passes\x22\x3A\x2225\x22,\x22yellow_cards\x22\x3A\x226\x22,\x22red_cards\x22\x3A\x220\x22,\x22position\x22\x3A\x22F\x20S\x22,\x22team_title\x22\x3A\x22Marseille\x22,\x22npg\x22\x3A\x2217\x22,\x22npxG\x22\x3A\x2216.21955289505422\x22,\x22xGChain\x22\x3A\x2217.558151353150606\x22,\x22xGBuildup\x22\x3A\x222.676426187157631\x22\x7D,\x7B\x22id\x22\x3A\x22942\x22,\x22player_name\x22\x3A\x22Florian\x20Thauvin\x22,\x22games\x22\x3A\x2238\x22,\x22time\x22\x3A\x222991\x22,\x22goals\x22\x3A\x2215\x22,\x22xG\x22\x3A\x229.62995583191514\x22,\x22assists\x22\x3A\x228\x22,\x22xA\x22\x3A\x228.574120261706412\x22,\x22shots\x22\x3A\x2295\x22,\x22key_passes\x22\x3A\x2261\x22,\x22yellow_cards\x22\x3A\x222\x22,\x22red_cards\x22\x3A\x220\x22,\x22position\x22\x3A\x22F\x20M\x20S\x22,\x22team_title\x22\x3A\x22Marseille\x22,\x22npg\x22\x3A\x2214\x22,\x22npxG\x22\x3A\x228.869860712438822\x22,\x22xGChain\x22\x3A\x2222.089292909950018\x22,\x22xGBuildup\x22\x3A\x2210.39108912460506\x22\x7D,\x7B\x22id\x22\x3A\x221817\x22,\x22player_name\x22\x3A\x22Mario\x20Balotelli\x22,\x22games\x22\x3A\x2223\x22,\x22time\x22\x3A\x221748\x22,\x22goals\x22\x3A\x2215\x22,\x22xG\x22\x3A\x2211.925692638382316\x22,\x22assists\x22\x3A\x221\x22,\x22xA\x22\x3A\x220.9889703020453453\x22,\x22shots\x22\x3A\x2275\x22,\x22key_passes\x22\x3A\x2210\x22,\x22yellow_cards\x22\x3A\x225\x22,\x22red_cards\x22\x3A\x223\x22,\x22position\x22\x3A\x22F\x20S\x22,\x22team_title\x22\x3A\x22Nice\x22,\x22npg\x22\x3A\x2212\x22,\x22npxG\x22\x3A\x228.88537366501987\x22,\x22xGChain\x22\x3A\x228.885695492848754\x22,\x22xGBuildup\x22\x3A\x222.278926068916917\x22\x7D,\x7B\x22id\x22\x3A\x223423\x22,\x22player_name\x22\x3A\x22Kylian\x20Mbappe\x2DLottin\x22,\x22games\x22\x3A\x2229 ...
# </script> </div>
# </div>
# </div>
# <div class="overlay is-hide"></div>
# <div class="modal is-hide">
# <div class="modal-header">
# <div class="modal-title"></div>
# <span class="modal-close"></span>
# </div>
# <div class="modal-body"></div>
# </div>
# <div class="grass-container">
# <div class="grass"></div>
# <div class="grass"></div>
# </div>
# <footer id="footer">
# <div class="footer-wrapper">
# <ul>
# <li><a href="league/EPL">EPL</a></li>
# <li><a href="league/La_liga">La liga</a></li>
# <li><a href="league/Bundesliga">Bundesliga</a></li>
# <li><a href="league/Serie_A">Serie A</a></li>
# <li><a href="league/Ligue_1">Ligue 1</a></li>
# <li><a href="league/RFPL">RFPL</a></li>
# </ul>
# <div><a href="mailto:support@understat.com">support@understat.com</a></div>
# <div>© understat 2017</div>
# </div>
# </footer>
# </div>
# <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>
# <script>
# 		WebFont.load({
# 			google: {
# 				families: ['Barlow:500', 'Anton']
# 			},
# 			active: function(){
# 				flagFontsLoading = true;
# 			}
# 		});
# 		var BASE_URL = 'https://understat.com/',
# 			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224356\x22\x7D') ;
# 	</script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>
# <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>
# <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>
# <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>
# <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>
# <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>
# <script>
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 		ga('create', 'UA-101482034-1', 'auto');
# 		ga('send', 'pageview');
#
# 					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
# 			</script>
# <script defer="" src="js/date.format.min.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/calendar.js?v=2.1" type="text/javascript"></script>
# <script defer="" src="js/league.js?v=2.8" type="text/javascript"></script>
# </body>
# </html>

# %%
bad_string = soup_league.find_all('script')

# %%
string = bad_string[2].string

# %%
ind_start = string.index("('")+2
ind_end = string.index("')")
json_data = string[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

data = json.loads(json_data)
data
columns = ['id','title','h_a','xG','npxG','npxGA','ppda','ppda_allowed','deep','deep_allowed',
           'scored','missed','xpts','result','date','wins','draws','loses','pts','npxGD']

# %%
data['162']
# Out:
# {'id': '162',
#  'title': 'SC Bastia',
#  'history': [{'h_a': 'h',
#    'xG': 0.828385,
#    'xGA': 0.664887,
#    'npxG': 0.828385,
#    'npxGA': 0.664887,
#    'ppda': {'att': 380, 'def': 30},
#    'ppda_allowed': {'att': 107, 'def': 26},
#    'deep': 0,
#    'deep_allowed': 3,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 1.4676,
#    'result': 'l',
#    'date': '2016-08-12 22:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': 0.16349800000000003},
#   {'h_a': 'a',
#    'xG': 2.25743,
#    'xGA': 0.349438,
#    'npxG': 1.49734,
#    'npxGA': 0.349438,
#    'ppda': {'att': 259, 'def': 12},
#    'ppda_allowed': {'att': 281, 'def': 25},
#    'deep': 7,
#    'deep_allowed': 2,
#    'scored': 3,
#    'missed': 0,
#    'xpts': 2.7301999999999995,
#    'result': 'w',
#    'date': '2016-08-20 22:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': 1.1479019999999998},
#   {'h_a': 'a',
#    'xG': 0.376246,
#    'xGA': 2.04065,
#    'npxG': 0.376246,
#    'npxGA': 1.28055,
#    'ppda': {'att': 221, 'def': 20},
#    'ppda_allowed': {'att': 208, 'def': 36},
#    'deep': 1,
#    'deep_allowed': 6,
#    'scored': 0,
#    'missed': 2,
#    'xpts': 0.23199999999999998,
#    'result': 'l',
#    'date': '2016-08-27 22:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -0.904304},
#   {'h_a': 'h',
#    'xG': 0.440568,
#    'xGA': 0.463047,
#    'npxG': 0.440568,
#    'npxGA': 0.463047,
#    'ppda': {'att': 149, 'def': 35},
#    'ppda_allowed': {'att': 117, 'def': 21},
#    'deep': 2,
#    'deep_allowed': 4,
#    'scored': 2,
#    'missed': 1,
#    'xpts': 1.2368,
#    'result': 'w',
#    'date': '2016-09-10 22:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': -0.02247899999999997},
#   {'h_a': 'a',
#    'xG': 0.991511,
#    'xGA': 2.2449,
#    'npxG': 0.991511,
#    'npxGA': 0.72471,
#    'ppda': {'att': 298, 'def': 17},
#    'ppda_allowed': {'att': 113, 'def': 35},
#    'deep': 3,
#    'deep_allowed': 11,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 0.4041,
#    'result': 'l',
#    'date': '2016-09-18 19:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': 0.26680100000000007},
#   {'h_a': 'h',
#    'xG': 0.319514,
#    'xGA': 0.0748124,
#    'npxG': 0.319514,
#    'npxGA': 0.0748124,
#    'ppda': {'att': 143, 'def': 32},
#    'ppda_allowed': {'att': 262, 'def': 28},
#    'deep': 4,
#    'deep_allowed': 1,
#    'scored': 0,
#    'missed': 0,
#    'xpts': 1.4723000000000002,
#    'result': 'd',
#    'date': '2016-09-21 21:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': 0.24470160000000002},
#   {'h_a': 'h',
#    'xG': 0.98055,
#    'xGA': 0.0771213,
#    'npxG': 0.98055,
#    'npxGA': 0.0771213,
#    'ppda': {'att': 96, 'def': 38},
#    'ppda_allowed': {'att': 203, 'def': 41},
#    'deep': 5,
#    'deep_allowed': 1,
#    'scored': 1,
#    'missed': 0,
#    'xpts': 2.3281,
#    'result': 'w',
#    'date': '2016-09-24 22:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': 0.9034287000000001},
#   {'h_a': 'a',
#    'xG': 0.764407,
#    'xGA': 1.55012,
#    'npxG': 0.764407,
#    'npxGA': 1.55012,
#    'ppda': {'att': 201, 'def': 19},
#    'ppda_allowed': {'att': 265, 'def': 41},
#    'deep': 3,
#    'deep_allowed': 2,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 0.7121999999999999,
#    'result': 'l',
#    'date': '2016-10-01 22:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -0.785713},
#   {'h_a': 'h',
#    'xG': 1.23731,
#    'xGA': 0.950062,
#    'npxG': 1.23731,
#    'npxGA': 0.950062,
#    'ppda': {'att': 230, 'def': 18},
#    'ppda_allowed': {'att': 269, 'def': 28},
#    'deep': 3,
#    'deep_allowed': 3,
#    'scored': 1,
#    'missed': 2,
#    'xpts': 1.6075,
#    'result': 'l',
#    'date': '2016-10-15 22:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': 0.28724799999999995},
#   {'h_a': 'a',
#    'xG': 0.200333,
#    'xGA': 1.74418,
#    'npxG': 0.200333,
#    'npxGA': 1.74418,
#    'ppda': {'att': 247, 'def': 25},
#    'ppda_allowed': {'att': 194, 'def': 30},
#    'deep': 3,
#    'deep_allowed': 4,
#    'scored': 1,
#    'missed': 2,
#    'xpts': 0.22100000000000003,
#    'result': 'l',
#    'date': '2016-10-22 22:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -1.543847},
#   {'h_a': 'h',
#    'xG': 2.00977,
#    'xGA': 0.61738,
#    'npxG': 2.00977,
#    'npxGA': 0.61738,
#    'ppda': {'att': 183, 'def': 27},
#    'ppda_allowed': {'att': 174, 'def': 28},
#    'deep': 8,
#    'deep_allowed': 2,
#    'scored': 0,
#    'missed': 0,
#    'xpts': 2.373,
#    'result': 'd',
#    'date': '2016-10-29 22:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': 1.39239},
#   {'h_a': 'a',
#    'xG': 0.643765,
#    'xGA': 2.8154,
#    'npxG': 0.643765,
#    'npxGA': 2.05531,
#    'ppda': {'att': 348, 'def': 21},
#    'ppda_allowed': {'att': 143, 'def': 26},
#    'deep': 0,
#    'deep_allowed': 7,
#    'scored': 1,
#    'missed': 2,
#    'xpts': 0.18209999999999998,
#    'result': 'l',
#    'date': '2016-11-05 23:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -1.4115449999999998},
#   {'h_a': 'h',
#    'xG': 0.701853,
#    'xGA': 1.42011,
#    'npxG': 0.701853,
#    'npxGA': 1.42011,
#    'ppda': {'att': 236, 'def': 25},
#    'ppda_allowed': {'att': 201, 'def': 15},
#    'deep': 4,
#    'deep_allowed': 4,
#    'scored': 1,
#    'missed': 1,
#    'xpts': 0.7403000000000001,
#    'result': 'd',
#    'date': '2016-11-19 23:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -0.718257},
#   {'h_a': 'a',
#    'xG': 1.03264,
#    'xGA': 2.03598,
#    'npxG': 1.03264,
#    'npxGA': 2.03598,
#    'ppda': {'att': 501, 'def': 28},
#    'ppda_allowed': {'att': 177, 'def': 20},
#    'deep': 1,
#    'deep_allowed': 4,
#    'scored': 1,
#    'missed': 1,
#    'xpts': 0.6107,
#    'result': 'd',
#    'date': '2016-11-27 20:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -1.00334},
#   {'h_a': 'h',
#    'xG': 0.941884,
#    'xGA': 1.12617,
#    'npxG': 0.941884,
#    'npxGA': 1.12617,
#    'ppda': {'att': 261, 'def': 23},
#    'ppda_allowed': {'att': 214, 'def': 22},
#    'deep': 3,
#    'deep_allowed': 2,
#    'scored': 1,
#    'missed': 1,
#    'xpts': 1.1846,
#    'result': 'd',
#    'date': '2016-11-30 22:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -0.18428599999999984},
#   {'h_a': 'a',
#    'xG': 0.311538,
#    'xGA': 1.76729,
#    'npxG': 0.311538,
#    'npxGA': 1.76729,
#    'ppda': {'att': 270, 'def': 10},
#    'ppda_allowed': {'att': 244, 'def': 31},
#    'deep': 0,
#    'deep_allowed': 11,
#    'scored': 0,
#    'missed': 5,
#    'xpts': 0.3173,
#    'result': 'l',
#    'date': '2016-12-03 23:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -1.455752},
#   {'h_a': 'h',
#    'xG': 0.947577,
#    'xGA': 0.871122,
#    'npxG': 0.947577,
#    'npxGA': 0.871122,
#    'ppda': {'att': 170, 'def': 22},
#    'ppda_allowed': {'att': 130, 'def': 22},
#    'deep': 3,
#    'deep_allowed': 2,
#    'scored': 2,
#    'missed': 0,
#    'xpts': 1.3737,
#    'result': 'w',
#    'date': '2016-12-10 23:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': 0.07645500000000005},
#   {'h_a': 'a',
#    'xG': 1.29477,
#    'xGA': 1.36607,
#    'npxG': 1.29477,
#    'npxGA': 1.36607,
#    'ppda': {'att': 323, 'def': 28},
#    'ppda_allowed': {'att': 123, 'def': 37},
#    'deep': 3,
#    'deep_allowed': 5,
#    'scored': 2,
#    'missed': 1,
#    'xpts': 1.3154000000000001,
#    'result': 'w',
#    'date': '2016-12-17 23:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': -0.07129999999999992},
#   {'h_a': 'h',
#    'xG': 2.35524,
#    'xGA': 1.52227,
#    'npxG': 2.35524,
#    'npxGA': 1.52227,
#    'ppda': {'att': 345, 'def': 29},
#    'ppda_allowed': {'att': 208, 'def': 29},
#    'deep': 7,
#    'deep_allowed': 5,
#    'scored': 1,
#    'missed': 2,
#    'xpts': 1.9917,
#    'result': 'l',
#    'date': '2016-12-21 23:50:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': 0.8329699999999998},
#   {'h_a': 'a',
#    'xG': 0.829962,
#    'xGA': 2.04745,
#    'npxG': 0.829962,
#    'npxGA': 2.04745,
#    'ppda': {'att': 255, 'def': 21},
#    'ppda_allowed': {'att': 273, 'def': 39},
#    'deep': 3,
#    'deep_allowed': 2,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 0.5113,
#    'result': 'l',
#    'date': '2017-01-14 23:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -1.217488},
#   {'h_a': 'h',
#    'xG': 1.13456,
#    'xGA': 1.49991,
#    'npxG': 1.13456,
#    'npxGA': 1.49991,
#    'ppda': {'att': 503, 'def': 40},
#    'ppda_allowed': {'att': 159, 'def': 20},
#    'deep': 3,
#    'deep_allowed': 6,
#    'scored': 1,
#    'missed': 1,
#    'xpts': 1.0676,
#    'result': 'd',
#    'date': '2017-01-20 22:45:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -0.36535000000000006},
#   {'h_a': 'h',
#    'xG': 1.0684,
#    'xGA': 2.08952,
#    'npxG': 1.0684,
#    'npxGA': 1.32942,
#    'ppda': {'att': 216, 'def': 20},
#    'ppda_allowed': {'att': 199, 'def': 24},
#    'deep': 7,
#    'deep_allowed': 4,
#    'scored': 1,
#    'missed': 1,
#    'xpts': 0.6229,
#    'result': 'd',
#    'date': '2017-01-28 22:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -0.26102000000000003},
#   {'h_a': 'a',
#    'xG': 0.902962,
#    'xGA': 1.61454,
#    'npxG': 0.902962,
#    'npxGA': 1.61454,
#    'ppda': {'att': 267, 'def': 27},
#    'ppda_allowed': {'att': 244, 'def': 28},
#    'deep': 2,
#    'deep_allowed': 7,
#    'scored': 1,
#    'missed': 2,
#    'xpts': 0.7961,
#    'result': 'l',
#    'date': '2017-02-04 19:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -0.711578},
#   {'h_a': 'a',
#    'xG': 1.28147,
#    'xGA': 2.60558,
#    'npxG': 1.28147,
#    'npxGA': 1.84549,
#    'ppda': {'att': 173, 'def': 11},
#    'ppda_allowed': {'att': 224, 'def': 27},
#    'deep': 2,
#    'deep_allowed': 7,
#    'scored': 1,
#    'missed': 4,
#    'xpts': 0.5263,
#    'result': 'l',
#    'date': '2017-02-11 19:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -0.56402},
#   {'h_a': 'h',
#    'xG': 0.63905,
#    'xGA': 1.23642,
#    'npxG': 0.63905,
#    'npxGA': 1.23642,
#    'ppda': {'att': 340, 'def': 16},
#    'ppda_allowed': {'att': 149, 'def': 21},
#    'deep': 3,
#    'deep_allowed': 10,
#    'scored': 1,
#    'missed': 1,
#    'xpts': 0.8139000000000001,
#    'result': 'd',
#    'date': '2017-02-17 19:45:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -0.5973700000000001},
#   {'h_a': 'a',
#    'xG': 0.504919,
#    'xGA': 2.81972,
#    'npxG': 0.504919,
#    'npxGA': 2.81972,
#    'ppda': {'att': 288, 'def': 13},
#    'ppda_allowed': {'att': 285, 'def': 29},
#    'deep': 6,
#    'deep_allowed': 7,
#    'scored': 0,
#    'missed': 3,
#    'xpts': 0.1509,
#    'result': 'l',
#    'date': '2017-02-25 19:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -2.3148009999999997},
#   {'h_a': 'h',
#    'xG': 1.73586,
#    'xGA': 1.8348,
#    'npxG': 1.73586,
#    'npxGA': 1.0747,
#    'ppda': {'att': 268, 'def': 8},
#    'ppda_allowed': {'att': 150, 'def': 24},
#    'deep': 0,
#    'deep_allowed': 4,
#    'scored': 2,
#    'missed': 2,
#    'xpts': 1.2345,
#    'result': 'd',
#    'date': '2017-03-01 18:30:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': 0.66116},
#   {'h_a': 'h',
#    'xG': 0.302025,
#    'xGA': 1.29564,
#    'npxG': 0.302025,
#    'npxGA': 1.29564,
#    'ppda': {'att': 270, 'def': 16},
#    'ppda_allowed': {'att': 140, 'def': 35},
#    'deep': 0,
#    'deep_allowed': 5,
#    'scored': 0,
#    'missed': 0,
#    'xpts': 0.4691,
#    'result': 'd',
#    'date': '2017-03-04 19:00:00',
#    'wins': 0,
#    'draws': 1,
#    'loses': 0,
#    'pts': 1,
#    'npxGD': -0.9936149999999999},
#   {'h_a': 'a',
#    'xG': 0.0781356,
#    'xGA': 3.28474,
#    'npxG': 0.0781356,
#    'npxGA': 3.28474,
#    'ppda': {'att': 288, 'def': 11},
#    'ppda_allowed': {'att': 186, 'def': 24},
#    'deep': 1,
#    'deep_allowed': 7,
#    'scored': 0,
#    'missed': 5,
#    'xpts': 0.0211,
#    'result': 'l',
#    'date': '2017-03-11 19:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -3.2066044000000002},
#   {'h_a': 'a',
#    'xG': 0.157698,
#    'xGA': 0.894507,
#    'npxG': 0.157698,
#    'npxGA': 0.894507,
#    'ppda': {'att': 279, 'def': 16},
#    'ppda_allowed': {'att': 280, 'def': 22},
#    'deep': 1,
#    'deep_allowed': 4,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 0.526,
#    'result': 'l',
#    'date': '2017-03-17 18:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -0.736809},
#   {'h_a': 'h',
#    'xG': 0.876256,
#    'xGA': 0.576916,
#    'npxG': 0.876256,
#    'npxGA': 0.576916,
#    'ppda': {'att': 321, 'def': 31},
#    'ppda_allowed': {'att': 171, 'def': 29},
#    'deep': 3,
#    'deep_allowed': 5,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 1.5901999999999998,
#    'result': 'l',
#    'date': '2017-04-01 18:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': 0.29934000000000005},
#   {'h_a': 'a',
#    'xG': 1.24836,
#    'xGA': 1.5652,
#    'npxG': 1.24836,
#    'npxGA': 1.5652,
#    'ppda': {'att': 324, 'def': 24},
#    'ppda_allowed': {'att': 148, 'def': 31},
#    'deep': 1,
#    'deep_allowed': 6,
#    'scored': 2,
#    'missed': 1,
#    'xpts': 1.1016,
#    'result': 'w',
#    'date': '2017-04-08 19:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': -0.31684},
#   {'h_a': 'h',
#    'xG': 0,
#    'xGA': 0,
#    'npxG': 0,
#    'npxGA': 0,
#    'ppda': {'att': 0, 'def': 0},
#    'ppda_allowed': {'att': 0, 'def': 0},
#    'deep': 0,
#    'deep_allowed': 0,
#    'scored': 0,
#    'missed': 3,
#    'xpts': 1.32,
#    'result': 'l',
#    'date': '2017-04-16 00:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': 0},
#   {'h_a': 'a',
#    'xG': 0.874853,
#    'xGA': 1.52837,
#    'npxG': 0.874853,
#    'npxGA': 1.52837,
#    'ppda': {'att': 287, 'def': 21},
#    'ppda_allowed': {'att': 207, 'def': 27},
#    'deep': 0,
#    'deep_allowed': 9,
#    'scored': 0,
#    'missed': 2,
#    'xpts': 0.8087,
#    'result': 'l',
#    'date': '2017-04-22 19:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -0.653517},
#   {'h_a': 'h',
#    'xG': 0.654212,
#    'xGA': 1.59306,
#    'npxG': 0.654212,
#    'npxGA': 1.59306,
#    'ppda': {'att': 300, 'def': 14},
#    'ppda_allowed': {'att': 223, 'def': 24},
#    'deep': 3,
#    'deep_allowed': 3,
#    'scored': 1,
#    'missed': 0,
#    'xpts': 0.53,
#    'result': 'w',
#    'date': '2017-04-29 19:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': -0.9388479999999999},
#   {'h_a': 'a',
#    'xG': 0.10292,
#    'xGA': 5.35893,
#    'npxG': 0.10292,
#    'npxGA': 4.59884,
#    'ppda': {'att': 393, 'def': 11},
#    'ppda_allowed': {'att': 149, 'def': 30},
#    'deep': 1,
#    'deep_allowed': 20,
#    'scored': 0,
#    'missed': 5,
#    'xpts': 0.0002,
#    'result': 'l',
#    'date': '2017-05-06 16:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -4.49592},
#   {'h_a': 'h',
#    'xG': 1.12194,
#    'xGA': 0.357563,
#    'npxG': 1.12194,
#    'npxGA': 0.357563,
#    'ppda': {'att': 223, 'def': 19},
#    'ppda_allowed': {'att': 225, 'def': 28},
#    'deep': 2,
#    'deep_allowed': 1,
#    'scored': 2,
#    'missed': 0,
#    'xpts': 2.1338999999999997,
#    'result': 'w',
#    'date': '2017-05-14 20:00:00',
#    'wins': 1,
#    'draws': 0,
#    'loses': 0,
#    'pts': 3,
#    'npxGD': 0.7643769999999999},
#   {'h_a': 'a',
#    'xG': 0.116759,
#    'xGA': 2.10282,
#    'npxG': 0.116759,
#    'npxGA': 2.10282,
#    'ppda': {'att': 306, 'def': 17},
#    'ppda_allowed': {'att': 172, 'def': 34},
#    'deep': 2,
#    'deep_allowed': 9,
#    'scored': 0,
#    'missed': 1,
#    'xpts': 0.1127,
#    'result': 'l',
#    'date': '2017-05-20 20:00:00',
#    'wins': 0,
#    'draws': 0,
#    'loses': 1,
#    'pts': 0,
#    'npxGD': -1.9860609999999999}]}

# %%
import understat_scraper 
import importlib
importlib.reload(understat_scraper)
# Out:
# <module 'understat_scraper' from '/home/cody/Documents/DataSciBC/EPLTransfer/get_data/Scrapers/understat_scraper.py'>

# %%
game_data = understat_scraper.get_game_stats()
# Out:
# Leagues:   0%|          | 0/6 [00:00<?, ?it/s]
# Years:   0%|          | 0/11 [00:00<?, ?it/s]
# Games:   0%|          | 0/20 [00:00<?, ?it/s]
# Games:   0%|          | 0/20 [00:00<?, ?it/s]
# Games:   0%|          | 0/20 [00:00<?, ?it/s]
# Games:   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 game_data = understat_scraper.get_game_stats()
#       2 game_data.get_stats()
#       3 game_data.data
#
# File ~/Documents/DataSciBC/EPLTransfer/get_data/Scrapers/understat_scraper.py:90, in get_game_stats.__init__(self)
#      88 self.leagues = ['EPL','La liga','Bundesliga','Serie A','Ligue 1','RFPL']
#      89 self.years = ['2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024']
# ---> 90 self.data = self.get_stats()
#
# File ~/Documents/DataSciBC/EPLTransfer/get_data/Scrapers/understat_scraper.py:101, in get_game_stats.get_stats(self)
#      99 for league in tqdm(self.leagues,position=0,leave=True,desc='Leagues',colour='green'):
#     100     for year in tqdm(self.years,position=1,leave=False,desc='Years',colour='red'):
# --> 101         page = requests.get(self.url + f'{league}/{year}')
#     102         game_soup = bs(page.text,'html.parser')
#     104         bad_string = game_soup.find_all('script')
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/urllib3/response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/urllib3/response.py:1209, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1207 if self.chunk_left == 0:
#    1208     break
# -> 1209 chunk = self._handle_chunk(amt)
#    1210 decoded = self._decode(
#    1211     chunk, decode_content=decode_content, flush_decoder=False
#    1212 )
#    1213 if decoded:
#
# File ~/miniconda3/envs/EPL/lib/python3.12/site-packages/urllib3/response.py:1146, in HTTPResponse._handle_chunk(self, amt)
#    1144     self.chunk_left = None
#    1145 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1146     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1147     self.chunk_left = self.chunk_left - amt
#    1148     returned_chunk = value
#
# File ~/miniconda3/envs/EPL/lib/python3.12/http/client.py:640, in HTTPResponse._safe_read(self, amt)
#     633 def _safe_read(self, amt):
#     634     """Read the number of bytes requested.
#     635
#     636     This function should be used when <amt> bytes "should" be present for
#     637     reading. If the bytes are truly not available (due to EOF), then the
#     638     IncompleteRead exception can be used to detect the problem.
#     639     """
# --> 640     data = self.fp.read(amt)
#     641     if len(data) < amt:
#     642         raise IncompleteRead(data, amt-len(data))
#
# File ~/miniconda3/envs/EPL/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/miniconda3/envs/EPL/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/EPL/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
