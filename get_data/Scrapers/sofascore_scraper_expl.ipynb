# %%
import importlib
import pandas as pd
import numpy as np
import sofascore_scraper as ss

importlib.reload(ss)
# Out:
# <module 'sofascore_scraper' from '/home/cody/Documents/DataSciBC/EPLTransfer/get_data/Scrapers/sofascore_scraper.py'>

# %%
data = ss.get_all_data().data
# Out:
# main loop:   0%|          | 0/4 [00:00<?, ?it/s]
# Failed to fetch data for match ID: 12437058, Status: 404
# Failed to fetch data for match ID: 12436545, Status: 404
# name 80
# shortName 80
# position 80
# height 80
# dateOfBirthTimestamp 80
# team 80
# date 80
# league 80
# season 80
# minutesPlayed 80
# rating 80
# accuratePass 80
# totalLongBalls 80
# accurateLongBalls 80
# keyPass 80
# totalPass 80
# totalCross 80
# accurateCross 80
# goalAssist 80
# savedShotsFromInsideTheBox 80
# saves 80
# totalKeeperSweeper 80
# accurateKeeperSweeper 80
# goalsPrevented 80
# touches 80
# possessionLostCtrl 80
# dispossessed 80
# expectedAssists 80
# aerialLost 80
# aerialWon 80
# duelLost 80
# duelWon 80
# challengeLost 80
# outfielderBlock 80
# totalContest 80
# interceptionWon 80
# wonContest 80
# totalTackle 80
# totalClearance 80
# blockedScoringAttempt 80
# hitWoodwork 80
# bigChanceCreated 80
# bigChanceMissed 80
# shotOffTarget 80
# onTargetScoringAttempt 80
# goals 80
# ...

# %%
data
# Out:
#                  name    shortName position  height dateOfBirthTimestamp  \
# 0   Emiliano Martínez  E. Martínez        G     195  1992-09-01 17:00:00
# 1          Matty Cash      M. Cash        D     185  1997-08-06 17:00:00
# 2          Ezri Konsa     E. Konsa        D     183  1997-10-22 17:00:00
# 3          Pau Torres    P. Torres        D     192  1997-01-15 16:00:00
# 4         Lucas Digne     L. Digne        D     178  1993-07-19 17:00:00
# ..                ...          ...      ...     ...                  ...
# 75    Odsonne Édouard   O. Édouard        F     187  1998-01-15 16:00:00
# 76      Remi Matthews  R. Matthews        G     184  1994-02-09 16:00:00
# 77      James Tomkins   J. Tomkins        D     192  1989-03-28 16:00:00
# 78         David Ozoh      D. Ozoh        M     183  2005-05-05 17:00:00
# 79   Naouirou Ahamada   N. Ahamada        M     183  2002-03-28 16:00:00
#
#               team                date          league season  minutesPlayed  \
# ...
