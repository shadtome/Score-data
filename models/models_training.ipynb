# %%
import importlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import base_line_models as blm
importlib.reload(blm)
# Out:
# <module 'base_line_models' from '/home/cody/Documents/DataSciBC/EPLTransfer/models/base_line_models.py'>

# %%
# Train Data
fd = '../data/main_data/train/train.csv'
train = pd.read_csv(fd)
train.head()
# Out:
#                  name         dob pos  height   foot        date  \
# 0         noah mbamba  2005-01-04   D   187.0  right  2024-02-03
# 1      zachary duncan  2000-05-29   M   183.0  right  2021-11-07
# 2        manuel neuer  1986-03-26   G   193.0  right  2024-10-19
# 3       mickel miller  1995-12-01   M   173.0   left  2024-04-12
# 4  gaetano monachello  1994-03-02   F   185.0   left  2016-05-15
#
#    market_value  adjusted_market_value                 team        league  \
# 0     3000000.0                3000000  Bayer 04 Leverkusen    Bundesliga
# 1      300000.0                 367916                  AGF   Superligaen
# 2     4000000.0                4000000    FC Bayern München    Bundesliga
# 3      250000.0                 250000      Plymouth Argyle  Championship
# 4      900000.0                1191864             Atalanta       Serie A
#
#    ...  red_card    rating  accuratePass  accurateLongBalls  accurateCross  \
# 0  ...       0.0  5.414286     13.523810           0.619048       0.047619
# 1  ...       0.0  6.545833      9.000000           0.458333       0.041667
# 2  ...       0.0  6.536864     27.122881           5.411017       0.000000
# 3  ...       0.0  6.551163     13.837209           0.697674       0.418605
# 4  ...       0.0  6.550000      5.700000           0.200000       0.100000
#
#    accurateKeeperSweeper  expectedAssists  expectedGoals   xGChain  xGBuildup
# 0               0.000000         0.025627       0.001195  0.000000   0.000000
# 1               0.000000         0.000000       0.000000  0.000000   0.000000
# 2               0.495763         0.001084       0.000969  0.271096   0.270107
# 3               0.000000         0.067950       0.015244  0.000000   0.000000
# 4               0.000000         0.000000       0.111925  0.161218   0.061587
#
# [5 rows x 55 columns]

# %%
# Base Line linear model with all of the features:
linReg = blm.Simple_Linear_Regression(train)
linReg.perform_CV()
# Out:
# MSE for train: mean: 49961930100825.71 std: 1766190834328.662
# MSE for test:  mean: 52623128336151.76  std: 16157787424203.045
#
# RMSE for train: mean: 7067261.791999064 std: 125462.60070582716
# RMSE for test: mean: 7167938.0340295015 std: 1115254.5343844378
#
# R^2 for train: mean: 0.4080075808979379 std: 0.006344560557093116
# R^2 for test: mean: 0.3709262457835678 std: 0.07693190732989633
#
# MAE for train: mean: 3607039.4571535764 std: 52779.976526211336
# MAE for test: mean: 3660546.333153973 std: 185378.77754387652
#
# MAPE for train: mean: 4.104013257779082 std: 0.05894752588706118
# MAPE for test: mean: 4.1451680329698934 std: 0.5716244798784486

# %%
quadReg = blm.Poly_Linear_Regression(train,quad_f=['age','rating','minutesPlayed'],cubic_f=['rating'])
quadReg.perform_CV()
# Out:
# MSE for train: mean: 48763263308777.83 std: 1742623634354.1633
# MSE for test:  mean: 51404929040818.23  std: 15913237144940.977
#
# RMSE for train: mean: 6981943.856848061 std: 125392.53805334955
# RMSE for test: mean: 7083984.905554068 std: 1105480.3927254272
#
# R^2 for train: mean: 0.42221354362096053 std: 0.0066987008829633215
# R^2 for test: mean: 0.385235001038978 std: 0.07775986632551567
#
# MAE for train: mean: 3603499.6812756127 std: 51805.46206553883
# MAE for test: mean: 3658173.905950642 std: 191054.33245671648
#
# MAPE for train: mean: 3.9784433396748553 std: 0.05984613348021624
# MAPE for test: mean: 4.026425243426426 std: 0.5890701628993441

# %%
pcaReg = blm.PCA_Linear_Regression(train)
pcaReg.perform_CV()
# Out:
# MSE for train: mean: 49961890413478.26 std: 1766188906761.5269
# MSE for test:  mean: 52622848502074.76  std: 16157959817915.78
#
# RMSE for train: mean: 7067258.98566631 std: 125462.51630280398
# RMSE for test: mean: 7167915.671386892 std: 1115272.805174125
#
# R^2 for train: mean: 0.408008050449283 std: 0.006344602459314034
# R^2 for test: mean: 0.3709311853819999 std: 0.07692853831502341
#
# MAE for train: mean: 3607026.1068573915 std: 52767.22646701328
# MAE for test: mean: 3660520.953842056 std: 185393.31987868156
#
# MAPE for train: mean: 4.103979418473823 std: 0.05898611374304905
# MAPE for test: mean: 4.145115542424592 std: 0.5714813750539797

# %%
# Decision Tree regressor
dtReg = blm.Tree_Reg(train,max_depth=6,type='DTR')
dtReg.perform_CV()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Decision Tree regressor
# ----> 2 dtReg = blm.Tree_Reg(train,max_depth=6,type='DTR')
#       3 dtReg.perform_CV()
#
# TypeError: Tree_Reg.__init__() got an unexpected keyword argument 'max_depth'

# %%
# Random Forest regressor
dtReg = blm.Tree_Reg(train,max_depth=6,type='RFR')
dtReg.perform_CV()
# Out:
# MSE for train: mean: 19563752755184.113 std: 357792512264.993
# MSE for test:  mean: 34788522520880.062  std: 9982307982405.943
#
# RMSE for train: mean: 4422908.486728994 std: 40413.774938079274
# RMSE for test: mean: 5835242.141099569 std: 859343.7470627113
#
# R^2 for train: mean: 0.7679966510607713 std: 0.0068149061861854186
# R^2 for test: mean: 0.5802057427879161 std: 0.06462107299190024
#
# MAE for train: mean: 2174233.772933945 std: 16547.46324998173
# MAE for test: mean: 2503902.2402910306 std: 171394.48164612768
#
# MAPE for train: mean: 1.8445016682042294 std: 0.02766251186198127
# MAPE for test: mean: 1.9305574184393621 std: 0.14388089142737384

# %%
# Gradient Boosting regressor
dtReg = blm.Tree_Reg(train,max_depth=6,type='GBR')
dtReg.perform_CV()
# Out:
# MSE for train: mean: 3830491732878.2617 std: 166990731262.79053
# MSE for test:  mean: 31499792481174.28  std: 9488184718351.047
#
# RMSE for train: mean: 1956700.7878379072 std: 42588.25839095525
# RMSE for test: mean: 5547667.19858543 std: 850400.5732086338
#
# R^2 for train: mean: 0.9545821924696121 std: 0.002092419964540316
# R^2 for test: mean: 0.6148265763966091 std: 0.09228510518755652
#
# MAE for train: mean: 1148732.208410807 std: 20713.692331027883
# MAE for test: mean: 2272827.514282276 std: 159174.6317338005
#
# MAPE for train: mean: 1.0292667823217172 std: 0.017253075555258585
# MAPE for test: mean: 1.3967969853617506 std: 0.09653904085119684

# %% [markdown]
# ### So Far
# Hence, so far, we have essentially a 7 million RMSE for each of these, with some slight differencs.
# Now the baseline tree models, specifically Random Forest and Gradient Boosting do the best on the training, but with some overfitting.  So if we can combat the overfitting, then we can obtain a really good model.
#
# Next, we would like construct some new models that improve these.
# ### Possible new models
# - Random Forest
# - XGBoost Regressor
# - XGBoost Regressor with Linear Regression on the final nodes
# - Ensamble of models based on position, normal players and star players

# %%
# Let look at each position and see what happens
pos = 'G'
LinReg_G = blm.Position_Linear_Regression(train,pos)
LinReg_G.perform_CV()
# Out:
# MSE for train: mean: 15376077652498.281 std: 923458172233.028
# MSE for test:  mean: 22252168390419.895  std: 9325120140516.807
#
# RMSE for train: mean: 3919457.5425609266 std: 118026.37230949831
# RMSE for test: mean: 4597156.430398425 std: 1057507.0424665308
#
# R^2 for train: mean: 0.4707882443542772 std: 0.014777393837151149
# R^2 for test: mean: 0.05209247580276388 std: 0.43744829013298875
#
# MAE for train: mean: 2260493.793206743 std: 61579.19793335345
# MAE for test: mean: 2615754.5547098857 std: 332941.6742587511
#
# MAPE for train: mean: 4.038788189987119 std: 0.06713772258439894
# MAPE for test: mean: 4.507670076557181 std: 0.864474211878482

# %%
pos = 'D'
LinReg_D = blm.Position_Linear_Regression(train,pos)
LinReg_D.perform_CV()
# Out:
# MSE for train: mean: 29006650731676.24 std: 1183191114899.9138
# MSE for test:  mean: 31422226650515.945  std: 10909557539605.3
#
# RMSE for train: mean: 5384655.152980716 std: 110179.92173923457
# RMSE for test: mean: 5515293.909572928 std: 1001878.1071286618
#
# R^2 for train: mean: 0.4498509005818138 std: 0.005853747763473316
# R^2 for test: mean: 0.4001644333767326 std: 0.0628295887841638
#
# MAE for train: mean: 3095107.198946501 std: 61569.22126420442
# MAE for test: mean: 3190164.7925204434 std: 324014.78721092455
#
# MAPE for train: mean: 3.613452230860787 std: 0.08970758080245159
# MAPE for test: mean: 3.67018207459697 std: 0.33338597946497506

# %%
pos = 'M'
LinReg_M = blm.Position_Linear_Regression(train,pos)
LinReg_M.perform_CV()
# Out:
# MSE for train: mean: 54762126593441.04 std: 2168703249862.8555
# MSE for test:  mean: 58893456799613.8  std: 19874745990804.31
#
# RMSE for train: mean: 7398675.615223406 std: 147396.5201067882
# RMSE for test: mean: 7567871.090823442 std: 1273100.1344327226
#
# R^2 for train: mean: 0.4134327213047003 std: 0.006457033794480738
# R^2 for test: mean: 0.37225735940066373 std: 0.05651196827287827
#
# MAE for train: mean: 3828274.2563324063 std: 59411.79345846555
# MAE for test: mean: 3938514.973577471 std: 229638.87656408965
#
# MAPE for train: mean: 4.1818014682556335 std: 0.08033499067590841
# MAPE for test: mean: 4.278945368407186 std: 0.6174187355653108

# %%
pos = 'F'
LinReg_F = blm.Position_Linear_Regression(train,pos)
LinReg_F.perform_CV()
# Out:
# MSE for train: mean: 69597503584640.766 std: 5312831198189.827
# MSE for test:  mean: 85200826286337.84  std: 54113224465670.42
#
# RMSE for train: mean: 8335954.836846585 std: 330697.0557697202
# RMSE for test: mean: 8869994.41817972 std: 2554217.1614407524
#
# R^2 for train: mean: 0.47297276966500607 std: 0.0074099032891145784
# R^2 for test: mean: 0.31549328401257015 std: 0.15622696166892755
#
# MAE for train: mean: 4317899.689620644 std: 111260.09259784422
# MAE for test: mean: 4567411.985617744 std: 410934.43106279086
#
# MAPE for train: mean: 4.249395877810461 std: 0.11760506326143896
# MAPE for test: mean: 4.426207193445929 std: 0.5968979489929466

# %% [markdown]
# So what the above 4 linear regressions says is that there is a lot of error in the midfield and forward positions because of the outliers that exist in those positions.
#
# So we should seperate the positions but also break apart the outliers in their own group to model.  I.e, maybe creat

# %% [markdown]
# First, let us do some hyperparameter tuning with respect to the random forest and Gradient boosting to see if we can even improve those even more.

# %%
fd_test = '../data/main_data/test/test.csv'
test = pd.read_csv(fd_test)

# %%
#Decision Tree
baseline = blm.Tree_Reg(train)
hyper_model = baseline.hyperparameter_Search()
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s[CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
#
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s[CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
#
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.2s[CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
#
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s[CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
#
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s[CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
#
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s[CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
#
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.4s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s[CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s[CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
#
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s[CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
#
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s[CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s[CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
#
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.4s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.3s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s

# %%
hyper_model.parameters
# Out:
# {'min_samples_split': 10,
#  'min_samples_leaf': 4,
#  'max_features': None,
#  'max_depth': 10}

# %%
print('Baseline Model:\n---------------')
print(f'parameters: {baseline.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~')
baseline.evaluate(test)
print('Hyperparameter tuned model\n---------------------------')
print(f'parameters:{hyper_model.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
hyper_model.evaluate(test)
# Out:
# Baseline Model:
# ---------------
# parameters: {'n_estimators': 100, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 43322394.47629978
# MSE for test:  80802095550783.12
#
# RMSE for train: 6581.974967766117
# RMSE for test: 8988998.584424358
#
# R^2 for train: 0.9999994866677074
# R^2 for test: 0.075114948365264
#
# MAE for train: 158.18159496103343
# MAE for test: 3367266.5523057217
#
# MAPE for train: 0.0004441641562958548
# MAPE for test: 1.643094173114781
#
# Hyperparameter tuned model
# ---------------------------
# parameters:{'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 10}
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 15709720600181.598
# MSE for test:  70963739069722.97
#
# RMSE for train: 3963548.990511105
# RMSE for test: 8423997.808031704
#
# R^2 for train: 0.771277957585339
# R^2 for test: 0.09539650112250775
#
# MAE for train: 1776667.027884261
# MAE for test: 2942001.858938403
#
# MAPE for train: 0.6208469603070103
# MAPE for test: 0.8952211577093175

# %%
# Random Forest Hyperparameter tuning:

baseline = blm.Tree_Reg(train,type='RFR')
hyper_model = baseline.hyperparameter_Search()
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.0s
# /home/cody/miniconda3/envs/EPL/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=False, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=False, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=False, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   5.1s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  13.7s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  15.9s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   8.3s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.9s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.9s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  21.3s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.8s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  18.6s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.2s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   4.9s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  31.5s
# [CV] END bootstrap=True, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  33.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   6.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  43.3s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  33.3s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  48.5s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  50.2s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  50.6s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  35.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  44.9s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   6.5s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  45.7s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   6.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   6.4s
# [CV] END bootstrap=True, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.8s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.2s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.5s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  48.3s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  16.7s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  28.0s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   4.3s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  19.6s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   8.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   8.0s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   9.2s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  29.9s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  32.8s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.3s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   6.3s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   8.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.0s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  29.3s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  30.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  30.5s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  40.9s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  34.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  35.1s
# [CV] END bootstrap=False, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  22.1s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  44.1s
# [CV] END bootstrap=False, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  17.8s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.9s
# [CV] END bootstrap=False, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   6.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  50.2s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  13.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  11.3s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  10.6s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  15.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  13.4s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.0s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.9s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  10.0s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  20.7s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   5.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   5.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   7.6s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.3s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  20.8s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   7.6s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.8s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   7.6s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  25.2s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   7.3s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   5.0s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   9.4s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   6.0s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   6.6s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   6.9s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=False, max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  11.5s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.9min
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=False, max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  13.5s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  26.9s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   6.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.4s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.9min
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.8s
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   5.2s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 2.0min
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.4min
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.6min
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  17.0s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  17.2s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  19.5s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   4.8s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   4.0s
# [CV] END bootstrap=False, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=False, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=False, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   7.1s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=False, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=False, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=False, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  47.9s
# [CV] END bootstrap=True, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  45.8s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  21.3s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  57.3s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  22.7s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  24.5s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END bootstrap=True, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  55.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.9s
# [CV] END bootstrap=True, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END bootstrap=False, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=False, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=False, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.7s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  23.8s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  51.8s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  13.6s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  11.9s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 1.7min
# [CV] END bootstrap=True, max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.0min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  51.0s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  12.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 1.7min
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.5min
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  18.9s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  17.0s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  18.4s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.6min
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   4.5s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   5.5s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   5.6s
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.8min
# [CV] END bootstrap=False, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  21.8s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  23.4s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  24.4s
# [CV] END bootstrap=False, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  24.0s
# [CV] END bootstrap=False, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  22.8s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  25.7s
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 1.3min

# %%
hyper_model.parameters
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 90,
#  'bootstrap': False}

# %%
print('Baseline Model:\n---------------')
print(f'parameters: {baseline.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~')
baseline.evaluate(test)
print('Hyperparameter tuned model\n---------------------------')
print(f'parameters:{hyper_model.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
hyper_model.evaluate(test)
# Out:
# Baseline Model:
# ---------------
# parameters: {'n_estimators': 100, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 7767747057636.004
# MSE for test:  73155947400584.77
#
# RMSE for train: 2787067.824369548
# RMSE for test: 8553125.0078895
#
# R^2 for train: 0.8359656401701208
# R^2 for test: -2.9068251671298535
#
# MAE for train: 1148446.3154409628
# MAE for test: 3372943.6832447844
#
# MAPE for train: 0.34003180161060287
# MAPE for test: 0.7992828131887769
#
# Hyperparameter tuned model
# ---------------------------
# parameters:{'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 90, 'bootstrap': False}
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 1999944051112.6135
# MSE for test:  50944610284489.375
#
# RMSE for train: 1414193.7813159176
# RMSE for test: 7137549.319233414
#
# R^2 for train: 0.9711705021362412
# R^2 for test: -0.47253706841055143
#
# MAE for train: 428491.74614144297
# MAE for test: 2758108.8986143214
#
# MAPE for train: 0.1786012573531819
# MAPE for test: 0.7175089971392122

# %%
#Gradient Boosting Regressor
baseline = blm.Tree_Reg(train,type='GBR')
hyper_model = baseline.hyperparameter_Search()
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   2.6s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   2.5s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   2.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   5.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   7.7s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   3.2s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   3.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   4.5s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  13.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.5s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   5.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  17.7s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   6.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  16.7s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   8.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  20.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   7.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   8.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  11.8s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  14.3s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  15.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   5.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  16.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  18.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  40.6s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  45.2s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  49.0s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.6s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  21.1s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  21.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  22.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  56.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  57.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  58.9s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   5.9s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   4.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time= 1.3min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  19.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   6.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  23.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time= 1.4min
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time= 1.4min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  27.1s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.2s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   6.4s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   6.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.9s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  13.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  40.9s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  43.3s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  41.9s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.1s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.3s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  15.0s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  16.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   7.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   8.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  30.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.8min
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  35.3s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 2.0min
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  29.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  33.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.9min
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  42.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  32.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   6.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   7.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.8s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.9s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.8s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   3.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  49.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  13.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.4min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  51.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  18.8s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  10.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   9.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.5min
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  20.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  13.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 1.1min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  31.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  20.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  18.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  36.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.8min
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   3.9s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  12.3s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.3s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   5.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  16.2s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.8s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  16.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  20.4s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.5s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  14.6s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  34.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  35.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  49.2s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  51.2s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.5s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  11.9s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  39.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  40.7s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.8s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.7s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  45.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  46.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.1min
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  22.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   9.3s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  24.4s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   4.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  14.4s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   6.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  13.7s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   4.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  10.8s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  13.4s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  23.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   7.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   7.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  23.8s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   5.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   6.9s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  30.9s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   7.4s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   7.6s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   8.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  17.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  16.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  16.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   5.5s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   5.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   5.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.3min
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  33.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  38.8s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  35.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  27.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.4min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  56.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  58.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.0min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  32.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   8.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   6.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  36.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   7.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   3.6s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 1.8min
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  17.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 1.9min
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  18.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  25.9s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  25.5s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.9s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  17.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 1.0min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  20.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 2.1min
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  15.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  27.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  22.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  12.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  24.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  34.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  56.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  58.1s

# %%
hyper_model.parameters
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 5,
#  'min_samples_leaf': 4,
#  'max_features': 'sqrt',
#  'max_depth': 5}

# %%
print('Baseline Model:\n---------------')
print(f'parameters: {baseline.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~')
baseline.evaluate(test)
print('Hyperparameter tuned model\n---------------------------')
print(f'parameters:{hyper_model.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
hyper_model.evaluate(test)
# Out:
# Baseline Model:
# ---------------
# parameters: {'n_estimators': 100, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 43381935.42563284
# MSE for test:  74950530866546.42
#
# RMSE for train: 6586.496445427784
# RMSE for test: 8657397.464974472
#
# R^2 for train: 0.9999994859348913
# R^2 for test: -2.225635066462171
#
# MAE for train: 273.8462619613382
# MAE for test: 3373635.5355879413
#
# MAPE for train: 0.00060210820563122
# MAPE for test: 0.8299144960002051
#
# Hyperparameter tuned model
# ---------------------------
# parameters:{'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 5}
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 6409654822261.552
# MSE for test:  43784894699356.5
#
# RMSE for train: 2531729.610811856
# RMSE for test: 6617015.543230686
#
# R^2 for train: 0.9084084954050096
# R^2 for test: 0.14172461243150158
#
# MAE for train: 1388039.2764582378
# MAE for test: 2586640.597170403
#
# MAPE for train: 1.1773864889972399
# MAPE for test: 1.3176949343100826
