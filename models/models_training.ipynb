# %%
import importlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import base_line_models as blm
importlib.reload(blm)
# Out:
# <module 'base_line_models' from '/home/cody/Documents/DataSciBC/EPLTransfer/models/base_line_models.py'>

# %%
# Train Data
fd = '../data/main_data/train/train.csv'
train = pd.read_csv(fd)
train.head()
# Out:
#                  name         dob pos  height   foot        date  \
# 0         noah mbamba  2005-01-04   D   187.0  right  2024-02-03
# 1      zachary duncan  2000-05-29   M   183.0  right  2021-11-07
# 2        manuel neuer  1986-03-26   G   193.0  right  2024-10-19
# 3       mickel miller  1995-12-01   M   173.0   left  2024-04-12
# 4  gaetano monachello  1994-03-02   F   185.0   left  2016-05-15
#
#    market_value  adjusted_market_value                 team        league  \
# 0     3000000.0                3000000  Bayer 04 Leverkusen    Bundesliga
# 1      300000.0                 367916                  AGF   Superligaen
# 2     4000000.0                4000000    FC Bayern München    Bundesliga
# 3      250000.0                 250000      Plymouth Argyle  Championship
# 4      900000.0                1191864             Atalanta       Serie A
#
#    ...  red_card    rating  accuratePass  accurateLongBalls  accurateCross  \
# 0  ...       0.0  5.414286     13.523810           0.619048       0.047619
# 1  ...       0.0  6.545833      9.000000           0.458333       0.041667
# 2  ...       0.0  6.536864     27.122881           5.411017       0.000000
# 3  ...       0.0  6.551163     13.837209           0.697674       0.418605
# 4  ...       0.0  6.550000      5.700000           0.200000       0.100000
#
#    accurateKeeperSweeper  expectedAssists  expectedGoals   xGChain  xGBuildup
# 0               0.000000         0.025627       0.001195  0.000000   0.000000
# 1               0.000000         0.000000       0.000000  0.000000   0.000000
# 2               0.495763         0.001084       0.000969  0.271096   0.270107
# 3               0.000000         0.067950       0.015244  0.000000   0.000000
# 4               0.000000         0.000000       0.111925  0.161218   0.061587
#
# [5 rows x 55 columns]

# %%
# Test data
fd = '../data/main_data/test/test.csv'
test = pd.read_csv(fd)
test.head()
# Out:
#               name         dob pos  height   foot        date  market_value  \
# 0      milan tucic  1996-08-14   F   186.0   left  2020-09-19      250000.0
# 1        yair mena  2000-06-27   M   176.0  right  2024-08-31       75000.0
# 2  nicolai remberg  2000-06-18   M   187.0  right  2024-10-20     1800000.0
# 3    babacar gueye  1994-12-30   F   192.0  right  2019-10-20      600000.0
# 4   sidnei tavares  2001-09-28   M   188.0  right  2024-09-28      400000.0
#
#    adjusted_market_value                 team                 league  ...  \
# 0                 310318  Oud-Heverlee Leuven       First Division A  ...
# 1                  75000    AVS - Futebol SAD  Liga Portugal Betclic  ...
# 2                1800000        Holstein Kiel             Bundesliga  ...
# 3                 757699      SC Paderborn 07             Bundesliga  ...
# 4                 400000           Moreirense  Liga Portugal Betclic  ...
#
#    red_card    rating  accuratePass  accurateLongBalls  accurateCross  \
# 0       0.0  0.000000      3.000000           0.000000       0.000000
# 1       0.0  6.600000      1.000000           0.000000       0.000000
# 2       0.0  6.657143      9.857143           0.571429       0.000000
# 3       0.0  6.746154     11.538462           0.153846       0.076923
# 4       0.0  6.512500     14.375000           0.250000       0.000000
#
#    accurateKeeperSweeper  expectedAssists  expectedGoals   xGChain  xGBuildup
# 0                    0.0         0.000000       0.000000  0.000000   0.000000
# 1                    0.0         0.000000       0.010860  0.000000   0.000000
# 2                    0.0         0.010549       0.055529  0.000000   0.000000
# 3                    0.0         0.049191       0.237336  0.182001   0.021479
# 4                    0.0         0.007285       0.008162  0.002600   0.000000
#
# [5 rows x 55 columns]

# %%
# Base Line linear model with all of the features:
linReg = blm.Simple_Linear_Regression(train)
linReg.perform_CV()
# Out:
# MSE for train: mean: 49961930100825.71 std: 1766190834328.662
# MSE for test:  mean: 52623128336151.76  std: 16157787424203.045
#
# RMSE for train: mean: 7067261.791999064 std: 125462.60070582716
# RMSE for test: mean: 7167938.0340295015 std: 1115254.5343844378
#
# R^2 for train: mean: 0.4080075808979379 std: 0.006344560557093116
# R^2 for test: mean: 0.3709262457835678 std: 0.07693190732989633
#
# MAE for train: mean: 3607039.4571535764 std: 52779.976526211336
# MAE for test: mean: 3660546.333153973 std: 185378.77754387652
#
# MAPE for train: mean: 4.104013257779082 std: 0.05894752588706118
# MAPE for test: mean: 4.1451680329698934 std: 0.5716244798784486

# %%
players = ['bukayo saka','erling haaland','jude bellingham','harry kane','william saliba','kai havertz','cody gakpo',
           'paulo dybala',]
for p in players:
    pred = linReg.predict_player(train,player=p)
    true = train[train['name'] == p].adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 40002178.342101 vs actual [140000000]
#
# player "erling haaland" has prediction 58293540.012280 vs actual [200000000]
#
# player "jude bellingham" has prediction 34513256.529054 vs actual [180000000]
#
# player "harry kane" has prediction 62411950.398940 vs actual [100000000]
#
# player "william saliba" has prediction 24675859.821847 vs actual [80000000]
#
# player "kai havertz" has prediction 29648159.932936 vs actual [75000000]
#
# player "cody gakpo" has prediction 21751476.073381 vs actual [55000000]
#
# player "paulo dybala" has prediction 35860470.639151 vs actual [20000000]

# %%
linReg.evaluate(test)
# Out:
# MSE for train: 50089555687254.57
# MSE for test:  69494351755615.98
#
# RMSE for train: 7077397.522200839
# RMSE for test: 8336327.234197082
#
# R^2 for train: 0.40648310037977187
# R^2 for test: 0.4006621287974872
#
# MAE for train: 3606015.87552913
# MAE for test: 3954620.7136484417
#
# MAPE for train: 2.5856440638924516
# MAPE for test: 4.369652572674384

# %%
log_linReg = blm.log_scale_Linear_Regression(train)
log_linReg.perform_CV()
# Out:
# MSE for train: mean: 0.9718164149663101 std: 0.006342523732242686
# MSE for test:  mean: 0.9921637184791535  std: 0.05613728312166448
#
# RMSE for train: mean: 0.9858022401021957 std: 0.0032184430712350804
# RMSE for test: mean: 0.9956784978400008 std: 0.028072182284833106
#
# R^2 for train: mean: 0.4981374205877124 std: 0.0034748163489597855
# R^2 for test: mean: 0.4863840926024496 std: 0.03369637922275653
#
# MAE for train: mean: 0.7713606371136246 std: 0.0022404362480961284
# MAE for test: mean: 0.777757425708384 std: 0.01935288010777617
#
# MAPE for train: mean: 0.055535082158550034 std: 0.00018568276535180768
# MAPE for test: mean: 0.05597502483068467 std: 0.001629273965097209

# %%
for p in players:
    pred = log_linReg.predict_player(train,player=p)
    true = train[train['name'] == p].adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 139645979.669270 vs actual [140000000]
#
# player "erling haaland" has prediction 344817631.195238 vs actual [200000000]
#
# player "jude bellingham" has prediction 78059535.385701 vs actual [180000000]
#
# player "harry kane" has prediction 396735691.229213 vs actual [100000000]
#
# player "william saliba" has prediction 34958847.321759 vs actual [80000000]
#
# player "kai havertz" has prediction 55587188.316538 vs actual [75000000]
#
# player "cody gakpo" has prediction 5696838.355380 vs actual [55000000]
#
# player "paulo dybala" has prediction 38557130.373270 vs actual [20000000]

# %%
log_linReg.evaluate(test)
# Out:
# MSE for train: 0.9727971028173446
# MSE for test:  1.0348721642939092
#
# RMSE for train: 0.9863047717705439
# RMSE for test: 1.0172866677067527
#
# R^2 for train: 0.49764441948171856
# R^2 for test: 0.47456141153943554
#
# MAE for train: 0.7716933122902829
# MAE for test: 0.795041184629238
#
# MAPE for train: 0.054958315054407514
# MAPE for test: 0.05656310891300309

# %%
quadReg = blm.Poly_Linear_Regression(train,quad_f=['age','rating','minutesPlayed'],cubic_f=['rating'])
quadReg.perform_CV()
# Out:
# MSE for train: mean: 49037787675982.734 std: 1753582221498.9282
# MSE for test:  mean: 51664028719166.51  std: 16026724442679.512
#
# RMSE for train: mean: 7001567.915623633 std: 125834.8079525311
# RMSE for test: mean: 7101562.681673368 std: 1109881.1636525134
#
# R^2 for train: mean: 0.4189640328791483 std: 0.006496130983010523
# R^2 for test: mean: 0.38241106672220365 std: 0.07649616193189543
#
# MAE for train: mean: 3597117.918943821 std: 53295.5081169906
# MAE for test: mean: 3651299.8117267354 std: 189632.82310362658
#
# MAPE for train: mean: 4.121586815537602 std: 0.07075292347452708
# MAPE for test: mean: 4.1670720578842495 std: 0.6449172911091515

# %%
for p in players:
    pred = quadReg.predict_player(train,player=p)
    true = train[train['name'] == p].adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 40710181.085550 vs actual [140000000]
#
# player "erling haaland" has prediction 61387121.387756 vs actual [200000000]
#
# player "jude bellingham" has prediction 35194865.074134 vs actual [180000000]
#
# player "harry kane" has prediction 57076542.761309 vs actual [100000000]
#
# player "william saliba" has prediction 25878929.545939 vs actual [80000000]
#
# player "kai havertz" has prediction 29094384.653951 vs actual [75000000]
#
# player "cody gakpo" has prediction 23351171.482019 vs actual [55000000]
#
# player "paulo dybala" has prediction 35574420.962602 vs actual [20000000]

# %%
quadReg.evaluate(test)
# Out:
# MSE for train: 49163779216529.055
# MSE for test:  68501693819571.91
#
# RMSE for train: 7011688.756393074
# RMSE for test: 8276575.005373413
#
# R^2 for train: 0.41745273213448464
# R^2 for test: 0.40922307625855703
#
# MAE for train: 3596824.97560183
# MAE for test: 3924204.961082451
#
# MAPE for train: 1.6720963969829672
# MAPE for test: 1.7619370007708763

# %%
log_quadReg = blm.log_scale_Poly_Linear_Regression(train,quad_f=['age','rating','minutesPlayed'],cubic_f=['rating'])
log_quadReg.perform_CV()
# Out:
# MSE for train: mean: 0.8526230353614185 std: 0.00593035421659786
# MSE for test:  mean: 0.869619432587764  std: 0.05208638478569779
#
# RMSE for train: mean: 0.9233702980769678 std: 0.003213719133680502
# RMSE for test: mean: 0.9321202157536208 std: 0.027772935948289928
#
# R^2 for train: mean: 0.5596927666606695 std: 0.002970829127323656
# R^2 for test: mean: 0.5499890964610296 std: 0.027705832034905675
#
# MAE for train: mean: 0.722919774053412 std: 0.0020299124275161002
# MAE for test: mean: 0.7287236247512944 std: 0.016584239436177137
#
# MAPE for train: mean: 0.051937467056075104 std: 0.00016417975657035324
# MAPE for test: mean: 0.052338701732166926 std: 0.0013083265214170947

# %%
for p in players:
    pred = log_quadReg.predict_player(train,player=p)
    true = train[train['name'] == p].adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 148427179.727560 vs actual [140000000]
#
# player "erling haaland" has prediction 635553588.580015 vs actual [200000000]
#
# player "jude bellingham" has prediction 65223187.368225 vs actual [180000000]
#
# player "harry kane" has prediction 136789564.641924 vs actual [100000000]
#
# player "william saliba" has prediction 44692630.215730 vs actual [80000000]
#
# player "kai havertz" has prediction 47298965.772055 vs actual [75000000]
#
# player "cody gakpo" has prediction 9503181.040301 vs actual [55000000]
#
# player "paulo dybala" has prediction 54451727.091557 vs actual [20000000]

# %%
log_quadReg.evaluate(test)
# Out:
# MSE for train: 0.8534433281280981
# MSE for test:  0.9097487471815374
#
# RMSE for train: 0.9238199652140552
# RMSE for test: 0.9538075000656775
#
# R^2 for train: 0.5592790960215832
# R^2 for test: 0.538090680118946
#
# MAE for train: 0.7232177106560003
# MAE for test: 0.7434297891309015
#
# MAPE for train: 0.05174970027491084
# MAPE for test: 0.05322283878384314

# %%
pcaReg = blm.PCA_Linear_Regression(train)
pcaReg.perform_CV()
# Out:
# MSE for train: mean: 49961890413478.26 std: 1766188906761.5269
# MSE for test:  mean: 52622848502074.76  std: 16157959817915.78
#
# RMSE for train: mean: 7067258.98566631 std: 125462.51630280398
# RMSE for test: mean: 7167915.671386892 std: 1115272.805174125
#
# R^2 for train: mean: 0.408008050449283 std: 0.006344602459314034
# R^2 for test: mean: 0.3709311853819999 std: 0.07692853831502341
#
# MAE for train: mean: 3607026.1068573915 std: 52767.22646701328
# MAE for test: mean: 3660520.953842056 std: 185393.31987868156
#
# MAPE for train: mean: 4.103979418473823 std: 0.05898611374304905
# MAPE for test: mean: 4.145115542424592 std: 0.5714813750539797

# %%
for p in players:
    pred = pcaReg.predict_player(train,player=p)
    true = train[train['name'] == p].adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 40003323.931250 vs actual [140000000]
#
# player "erling haaland" has prediction 58291276.380666 vs actual [200000000]
#
# player "jude bellingham" has prediction 34517515.138743 vs actual [180000000]
#
# player "harry kane" has prediction 62402770.322901 vs actual [100000000]
#
# player "william saliba" has prediction 24675434.271576 vs actual [80000000]
#
# player "kai havertz" has prediction 29649577.411088 vs actual [75000000]
#
# player "cody gakpo" has prediction 21755222.022391 vs actual [55000000]
#
# player "paulo dybala" has prediction 35857646.780582 vs actual [20000000]

# %%
# Decision Tree regressor
dtReg = blm.Tree_Reg(train,type='DTR')
dtReg.perform_CV()
# Out:
# MSE for train: mean: 38509023.58815471 std: 14954536.338339996
# MSE for test:  mean: 70564906707687.6  std: 25721713531863.547
#
# RMSE for train: mean: 6020.301174585208 std: 1504.9908157336608
# RMSE for test: mean: 8272689.412236239 std: 1458600.9037300213
#
# R^2 for train: mean: 0.9999995448809553 std: 1.754663615400618e-07
# R^2 for test: mean: 0.11600899488418177 std: 0.34856011436883455
#
# MAE for train: mean: 140.60669649501438 std: 43.845745611877845
# MAE for test: mean: 3208365.938812324 std: 298026.89120997966
#
# MAPE for train: mean: 0.0005679999265820826 std: 0.00015315518748678741
# MAPE for test: mean: 1.624016130021563 std: 0.17684768744020873

# %%
# Random Forest regressor
dtReg = blm.Tree_Reg(train,type='RFR')
dtReg.perform_CV()
# Out:
# MSE for train: mean: 4384725266525.62 std: 176855554513.28766
# MSE for test:  mean: 30681689386304.945  std: 8706471166997.88
#
# RMSE for train: mean: 2093552.0493077699 std: 42012.89522108648
# RMSE for test: mean: 5479787.166124461 std: 808468.9235107214
#
# R^2 for train: mean: 0.948022464440103 std: 0.0019202424719388471
# R^2 for test: mean: 0.6270374677404627 std: 0.07428387968035481
#
# MAE for train: mean: 856790.9837086307 std: 9765.3968378528
# MAE for test: mean: 2302626.814341518 std: 154881.17854810713
#
# MAPE for train: mean: 0.540163843023639 std: 0.008260948045073765
# MAPE for test: mean: 1.4674922498760874 std: 0.1169339555849723

# %%
# Gradient Boosting regressor
dtReg = blm.Tree_Reg(train,type='GBR')
dtReg.perform_CV()
# Out:
# MSE for train: mean: 38568563.45999961 std: 14955075.749270404
# MSE for test:  mean: 61653416225399.664  std: 22727461398340.273
#
# RMSE for train: mean: 6025.769728059613 std: 1502.8847741593456
# RMSE for test: mean: 7733974.725109006 std: 1356116.2106452098
#
# R^2 for train: mean: 0.9999995441754479 std: 1.754663614164034e-07
# R^2 for test: mean: 0.2199832458202223 std: 0.3390343603580478
#
# MAE for train: mean: 256.27941331623435 std: 43.7557161217106
# MAE for test: mean: 3045498.094417673 std: 247173.90992669144
#
# MAPE for train: mean: 0.000726468221984113 std: 0.00015298422545464218
# MAPE for test: mean: 1.5974389471967054 std: 0.1387847908072493

# %% [markdown]
# ### So Far
# Hence, so far, we have essentially a 7 million RMSE for each of these, with some slight differencs.
# Now the baseline tree models, specifically Random Forest and Gradient Boosting do the best on the training, but with some overfitting.  So if we can combat the overfitting, then we can obtain a really good model.
#
# Next, we would like construct some new models that improve these.
# ### Possible new models
# - Random Forest
# - XGBoost Regressor
# - XGBoost Regressor with Linear Regression on the final nodes
# - Ensamble of models based on position, normal players and star players

# %%
# Let look at each position and see what happens
pos = 'G'
LinReg_G = blm.Position_Linear_Regression(train,pos)
LinReg_G.perform_CV()
# Out:
# MSE for train: mean: 15376077652498.281 std: 923458172233.028
# MSE for test:  mean: 22252168390419.895  std: 9325120140516.807
#
# RMSE for train: mean: 3919457.5425609266 std: 118026.37230949831
# RMSE for test: mean: 4597156.430398425 std: 1057507.0424665308
#
# R^2 for train: mean: 0.4707882443542772 std: 0.014777393837151149
# R^2 for test: mean: 0.05209247580276388 std: 0.43744829013298875
#
# MAE for train: mean: 2260493.793206743 std: 61579.19793335345
# MAE for test: mean: 2615754.5547098857 std: 332941.6742587511
#
# MAPE for train: mean: 4.038788189987119 std: 0.06713772258439894
# MAPE for test: mean: 4.507670076557181 std: 0.864474211878482

# %%
pos = 'D'
LinReg_D = blm.Position_Linear_Regression(train,pos)
LinReg_D.perform_CV()
# Out:
# MSE for train: mean: 29006650731676.24 std: 1183191114899.9138
# MSE for test:  mean: 31422226650515.945  std: 10909557539605.3
#
# RMSE for train: mean: 5384655.152980716 std: 110179.92173923457
# RMSE for test: mean: 5515293.909572928 std: 1001878.1071286618
#
# R^2 for train: mean: 0.4498509005818138 std: 0.005853747763473316
# R^2 for test: mean: 0.4001644333767326 std: 0.0628295887841638
#
# MAE for train: mean: 3095107.198946501 std: 61569.22126420442
# MAE for test: mean: 3190164.7925204434 std: 324014.78721092455
#
# MAPE for train: mean: 3.613452230860787 std: 0.08970758080245159
# MAPE for test: mean: 3.67018207459697 std: 0.33338597946497506

# %%
pos = 'M'
LinReg_M = blm.Position_Linear_Regression(train,pos)
LinReg_M.perform_CV()
# Out:
# MSE for train: mean: 54762126593441.04 std: 2168703249862.8555
# MSE for test:  mean: 58893456799613.8  std: 19874745990804.31
#
# RMSE for train: mean: 7398675.615223406 std: 147396.5201067882
# RMSE for test: mean: 7567871.090823442 std: 1273100.1344327226
#
# R^2 for train: mean: 0.4134327213047003 std: 0.006457033794480738
# R^2 for test: mean: 0.37225735940066373 std: 0.05651196827287827
#
# MAE for train: mean: 3828274.2563324063 std: 59411.79345846555
# MAE for test: mean: 3938514.973577471 std: 229638.87656408965
#
# MAPE for train: mean: 4.1818014682556335 std: 0.08033499067590841
# MAPE for test: mean: 4.278945368407186 std: 0.6174187355653108

# %%
pos = 'F'
LinReg_F = blm.Position_Linear_Regression(train,pos)
LinReg_F.perform_CV()
# Out:
# MSE for train: mean: 69597503584640.766 std: 5312831198189.827
# MSE for test:  mean: 85200826286337.84  std: 54113224465670.42
#
# RMSE for train: mean: 8335954.836846585 std: 330697.0557697202
# RMSE for test: mean: 8869994.41817972 std: 2554217.1614407524
#
# R^2 for train: mean: 0.47297276966500607 std: 0.0074099032891145784
# R^2 for test: mean: 0.31549328401257015 std: 0.15622696166892755
#
# MAE for train: mean: 4317899.689620644 std: 111260.09259784422
# MAE for test: mean: 4567411.985617744 std: 410934.43106279086
#
# MAPE for train: mean: 4.249395877810461 std: 0.11760506326143896
# MAPE for test: mean: 4.426207193445929 std: 0.5968979489929466

# %% [markdown]
# So what the above 4 linear regressions says is that there is a lot of error in the midfield and forward positions because of the outliers that exist in those positions.
#
# So we should seperate the positions but also break apart the outliers in their own group to model.  I.e, maybe creat

# %% [markdown]
# First, let us do some hyperparameter tuning with respect to the random forest and Gradient boosting to see if we can even improve those even more.

# %%
fd_test = '../data/main_data/test/test.csv'
test = pd.read_csv(fd_test)

# %%
#Decision Tree
baseline = blm.Tree_Reg(train)
hyper_model = baseline.hyperparameter_Search()
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s[CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s[CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
#
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.3s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s[CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
#
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.4s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.4s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.4s[CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
#
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s[CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
#
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.4s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.4s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s[CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.3s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s[CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s[CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s[CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
#
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.3s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.4s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.6s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.5s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.5s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.4s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.3s[CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
#
# [CV] END max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.3s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.3s
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s

# %%
hyper_model.parameters
# Out:
# {'n_estimators': 100,
#  'max_depth': 10,
#  'max_features': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'bootstrap': True}

# %%
print('Baseline Model:\n---------------')
print(f'parameters: {baseline.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~')
baseline.evaluate(test)
print('Hyperparameter tuned model\n---------------------------')
print(f'parameters:{hyper_model.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
hyper_model.evaluate(test)
# Out:
# Baseline Model:
# ---------------
# parameters: {'n_estimators': 100, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 43322394.47629978
# MSE for test:  89197065022907.05
#
# RMSE for train: 6581.974967766117
# RMSE for test: 9444419.782226278
#
# R^2 for train: 0.9999994866677074
# R^2 for test: 0.034108234025071016
#
# MAE for train: 158.18159496103343
# MAE for test: 3407936.716695132
#
# MAPE for train: 0.0004441641562958548
# MAPE for test: 1.5993789157984473
#
# Hyperparameter tuned model
# ---------------------------
# parameters:{'n_estimators': 100, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 15709720600181.598
# MSE for test:  71641266341360.02
#
# RMSE for train: 3963548.990511105
# RMSE for test: 8464116.39460139
#
# R^2 for train: 0.771277957585339
# R^2 for test: 0.08344288104697462
#
# MAE for train: 1776667.027884261
# MAE for test: 2958641.790287031
#
# MAPE for train: 0.6208469603070103
# MAPE for test: 0.8967501459272842

# %%
# Random Forest Hyperparameter tuning:

baseline = blm.Tree_Reg(train,type='RFR')
hyper_model = baseline.hyperparameter_Search()
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END bootstrap=True, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   3.3s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   4.0s
# [CV] END bootstrap=True, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   4.0s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   4.2s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   4.6s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   4.4s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   5.2s
# [CV] END bootstrap=True, max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.2s
# [CV] END bootstrap=True, max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.1s
# [CV] END bootstrap=True, max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   6.6s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   6.6s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   9.3s
# [CV] END bootstrap=True, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=True, max_depth=60, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  20.3s
# [CV] END bootstrap=True, max_depth=60, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  18.8s
# [CV] END bootstrap=True, max_depth=60, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  23.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  41.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  50.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  52.5s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  59.0s
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.2min
# [CV] END bootstrap=False, max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time= 1.2min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  10.5s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   9.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.3s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   3.5s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.0s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  11.0s
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  59.3s
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  44.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  13.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  10.8s
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  41.8s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  13.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.5s
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   7.4s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   9.3s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   8.1s
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  43.7s
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  50.7s
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  49.7s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  19.8s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  19.7s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  18.7s
# [CV] END bootstrap=False, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=False, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.6min
# [CV] END bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.7min
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.6min
# [CV] END bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.7min
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.7min
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  17.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   3.9s
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  14.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  14.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  14.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  12.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   3.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  13.7s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  51.4s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  48.4s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  48.1s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.1s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.4s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END bootstrap=True, max_depth=60, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  55.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time= 1.0min
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  42.7s
# [CV] END bootstrap=True, max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  23.2s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  28.8s
# [CV] END bootstrap=True, max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  26.0s
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  48.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  42.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  43.6s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   6.7s
# [CV] END bootstrap=False, max_depth=10, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  44.2s
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  50.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  12.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=False, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=False, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=False, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  57.7s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  16.7s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.7s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.5s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.1min
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  26.7s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.1min
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  28.2s
# [CV] END bootstrap=True, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  28.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  35.2s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  35.8s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  36.0s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   3.8s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   3.7s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   3.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   4.0s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   3.6s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   3.9s
# [CV] END bootstrap=True, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  36.5s
# [CV] END bootstrap=True, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  38.2s
# [CV] END bootstrap=True, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  39.6s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   6.5s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   6.6s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   7.3s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   5.3s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   4.4s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  20.3s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  22.3s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   6.3s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  25.1s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  22.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.3s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.5s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.5s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  43.1s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.1min
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  53.6s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  57.2s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.2min
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.2min
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 1.2min
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.2min
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.3s
# [CV] END bootstrap=True, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=4, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=False, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END bootstrap=True, max_depth=90, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   5.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   7.5s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   9.0s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   9.0s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   5.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   4.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=False, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  19.0s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  22.1s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  24.8s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 1.9min
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=4, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.7min
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 2.0min
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.9s
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.8min
# [CV] END bootstrap=False, max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time= 3.8min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time= 3.7min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 1.3min
# [CV] END bootstrap=True, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time= 4.0min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 1.5min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 1.5min
# [CV] END bootstrap=True, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  15.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  44.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  47.0s
# [CV] END bootstrap=True, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  19.1s
# [CV] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  52.3s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  14.7s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  13.4s
# [CV] END bootstrap=True, max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  14.6s
# [CV] END bootstrap=True, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 1.9min
# [CV] END bootstrap=True, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 1.6min
# [CV] END bootstrap=True, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 1.5min
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time= 1.6min
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time= 1.7min
# [CV] END bootstrap=False, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time= 1.6min
# [CV] END bootstrap=True, max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 5.3min
# [CV] END bootstrap=True, max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 5.4min
# [CV] END bootstrap=True, max_depth=60, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 5.2min

# %%
hyper_model.parameters
# Out:
# {'n_estimators': 200,
#  'max_depth': None,
#  'max_features': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'bootstrap': True}

# %%
print('Baseline Model:\n---------------')
print(f'parameters: {baseline.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~')
baseline.evaluate(test)
print('Hyperparameter tuned model\n---------------------------')
print(f'parameters:{hyper_model.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
hyper_model.evaluate(test)
# Out:
# Baseline Model:
# ---------------
# parameters: {'n_estimators': 100, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 4270024759873.5234
# MSE for test:  45982680274107.125
#
# RMSE for train: 2066403.8230398055
# RMSE for test: 6781053.03578339
#
# R^2 for train: 0.9325935160220175
# R^2 for test: -0.022333966799508387
#
# MAE for train: 848870.5377047107
# MAE for test: 2531838.1382767577
#
# MAPE for train: 0.2699799099759658
# MAPE for test: 0.7011877117888891
#
# Hyperparameter tuned model
# ---------------------------
# parameters:{'n_estimators': 200, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 11022211382622.617
# MSE for test:  73798828327333.36
#
# RMSE for train: 3319971.593646942
# RMSE for test: 8590624.443387883
#
# R^2 for train: 0.8497768955510876
# R^2 for test: 0.10920930216754787
#
# MAE for train: 1169087.203673484
# MAE for test: 3115278.9469765364
#
# MAPE for train: 0.3060189961034894
# MAPE for test: 1.2250415324113382

# %%
#Gradient Boosting Regressor
baseline = blm.Tree_Reg(train,type='GBR')
hyper_model = baseline.hyperparameter_Search()
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.7s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.0s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.9s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  27.2s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  27.6s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  28.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  28.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  31.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  31.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  13.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  44.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  16.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  16.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  48.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  51.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   4.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  41.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 2.1min
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 2.1min
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 2.2min
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  24.1s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=30, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=30, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  17.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.9s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  21.2s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  22.8s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  17.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.2min
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.4min
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.5min
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 4.2min
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 4.3min
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 4.3min
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  27.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.4s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  25.0s
# [CV] END max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  19.8s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   5.3s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   4.8s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.3s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   4.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  28.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  28.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  31.1s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 2.9min
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  59.1s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  43.9s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 1.4min
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time= 1.4min
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.2min
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.0min
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.5min
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.8s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.6s
# [CV] END max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  29.3s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.6min
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   5.9s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  12.2s
# [CV] END max_depth=1, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  14.0s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  28.8s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=  46.1s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  29.2s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  27.4s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  34.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   7.7s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   5.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   6.1s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 9.7min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=10.0min
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  31.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 9.9min
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.0s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  10.5s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.0s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   9.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  38.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  11.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   8.5s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  11.7s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  12.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   4.5s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   4.4s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  14.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  55.9s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   3.4s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   3.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   3.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  18.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  28.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  29.8s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  18.0s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  13.9s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   6.0s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   5.1s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   9.7s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   5.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   8.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   9.7s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   9.8s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  51.1s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=11.3min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  41.7s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   3.5s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=11.7min
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.3s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   4.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  29.9s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=11.8min
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   9.5s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.5s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.3s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  20.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  20.1s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  44.4s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  39.9s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=  42.9s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 1.0min
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 1.2min
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 1.2min
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  26.5s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  34.3s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=12.3min
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=  39.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  10.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  11.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   6.9s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=12.3min
# [CV] END max_depth=30, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=13.6min
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   3.4s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  18.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   8.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   7.7s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=28.5min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=28.6min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=26.8min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=29.5min
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  33.7s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  27.5s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.5s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.5s
# [CV] END max_depth=30, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END max_depth=60, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  19.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  11.8s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   7.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   8.2s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  11.6s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  12.6s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  15.2s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  39.6s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  37.9s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  33.2s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=29.7min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=30.7min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 2.3min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 3.2min
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  10.6s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  15.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  10.8s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.8s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 4.2min
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 4.9min
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 6.6min
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   7.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  49.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  39.8s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 6.8min
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   6.8s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   5.5s
# [CV] END max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.8s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  48.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  23.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  26.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 6.4min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time= 1.5min
# [CV] END max_depth=60, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 7.0min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time= 1.4min
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.4s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.6s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.8s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   3.6s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   5.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   5.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time= 1.2min
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  53.2s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=55.9min
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  35.1s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  33.8s
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=60.1min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=61.2min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   3.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.1s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   3.7s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   4.3s
# [CV] END max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   5.2s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   2.2s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   6.6s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   5.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 5.7min
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  22.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  24.5s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 6.0min
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  25.8s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  32.9s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  29.1s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  29.6s
# [CV] END max_depth=90, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  35.7s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.7s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   4.3s
# [CV] END max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.4s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  43.0s
# [CV] END max_depth=2, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  50.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  13.3s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  17.8s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  14.3s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.7s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.0s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   5.6s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   3.8s
# [CV] END max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.3s
# [CV] END max_depth=90, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time= 6.7min
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=49.5min
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=23.1min
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=27.4min
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=44.4min
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=28.0min
# [CV] END max_depth=60, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=45.1min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=63.1min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=63.3min
# [CV] END max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=64.3min
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=75.0min
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=80.9min
# [CV] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=81.5min

# %%
hyper_model.parameters
# Out:
# {'n_estimators': 100,
#  'max_depth': 5,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'bootstrap': True}

# %%
print('Baseline Model:\n---------------')
print(f'parameters: {baseline.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~')
baseline.evaluate(test)
print('Hyperparameter tuned model\n---------------------------')
print(f'parameters:{hyper_model.parameters}\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
hyper_model.evaluate(test)
# Out:
# Baseline Model:
# ---------------
# parameters: {'n_estimators': 100, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 43381935.42563284
# MSE for test:  78211414232683.02
#
# RMSE for train: 6586.496445427784
# RMSE for test: 8843721.741025269
#
# R^2 for train: 0.9999994859348913
# R^2 for test: 0.10000865530162473
#
# MAE for train: 273.8462619613382
# MAE for test: 3261693.7599034444
#
# MAPE for train: 0.00060210820563122
# MAPE for test: 1.397990798338663
#
# Hyperparameter tuned model
# ---------------------------
# parameters:{'n_estimators': 100, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'bootstrap': True}
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MSE for train: 33771249945839.043
# MSE for test:  78207927573023.45
#
# RMSE for train: 5811303.635660336
# RMSE for test: 8843524.612563899
#
# R^2 for train: 0.33289038162628715
# R^2 for test: -0.3268528192147997
#
# MAE for train: 2686012.844718756
# MAE for test: 3285869.0671111057
#
# MAPE for train: 0.7965548108131633
# MAPE for test: 0.9306504332520023
