# %%
import importlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import base_line_models_ba_6 as blm
importlib.reload(blm)
# Out:
# <module 'base_line_models_ba_6' from '/home/cody/Documents/DataSciBC/EPLTransfer/models/base_line_models_ba_6.py'>

# %%
# Train Data
fd = '../data/main_data/test/test_ba_12.csv'
test = pd.read_csv(fd)
test.head()
# Out:
#              name         dob pos  height   foot        date  \
# 0    cengiz under  1997-07-13   M   173.0   left  2022-05-21
# 1       adam lang  1993-01-16   D   188.0  right  2016-12-18
# 2  graham dorrans  1987-05-04   M   175.0  right  2016-03-12
# 3     lars kramer  1999-07-10   D   192.0  right  2023-06-03
# 4      diego rico  1993-02-22   D   181.0   left  2023-10-08
#
#    market_value_before  adjusted_market_value_before                    team  \
# 0           22000000.0                      25555693  Olympique de Marseille
# 1            1000000.0                       1324294                   Dijon
# 2            3500000.0                       4635029            Norwich City
# 3             750000.0                        792251                     AaB
# 4            3000000.0                       3169007                  Getafe
#
#                           league  ...  red_card_y  rating_y  accuratePass_y  \
# 0                        Ligue 1  ...         0.0  7.021622       19.162162
# 1                        Ligue 1  ...         1.0  6.620000       25.900000
# 2                 Premier League  ...         0.0  7.134615       39.653846
# 3  Superligaen, Relegation round  ...         0.0  6.860000       58.200000
# 4                         LaLiga  ...         0.0  6.944737       20.131579
#
#    accurateLongBalls_y  accurateCross_y  accurateKeeperSweeper_y  \
# 0             1.297297         1.027027                      0.0
# 1             2.700000         0.100000                      0.0
# 2             4.500000         0.384615                      0.0
# 3             3.600000         0.000000                      0.0
# 4             2.157895         1.157895                      0.0
#
#    expectedAssists_y  expectedGoals_y  xGChain_y  xGBuildup_y
# 0           0.200719         0.225459   0.511961     0.180453
# 1           0.004503         0.024602   0.133950     0.128520
# 2           0.006703         0.006356   0.032523     0.025273
# 3           0.000000         0.000000   0.000000     0.000000
# 4           0.097172         0.012979   0.168207     0.096036
#
# [5 rows x 103 columns]

# %%
# Train Data
fd = '../data/main_data/train/train_ba_12.csv'
train = pd.read_csv(fd)
train.head()
# Out:
#                 name         dob pos  height   foot        date  \
# 0  jens petter hauge  1999-10-11   F   184.0  right  2023-01-19
# 1    jon karrikaburu  2002-09-18   F   183.0  right  2022-09-11
# 2       maxime lopez  1997-12-03   M   167.0  right  2023-06-02
# 3         luis silva  1999-02-17   D   184.0   left  2020-01-26
# 4     tanguy nianzou  2002-06-06   D   192.0  right  2023-06-04
#
#    market_value_before  adjusted_market_value_before           team  \
# 0            3000000.0                       3169007       KAA Gent
# 1            5000000.0                       5808112  Real Sociedad
# 2           15000000.0                      15845036       Sassuolo
# 3             450000.0                        558573          B-SAD
# 4            7500000.0                       7922518        Sevilla
#
#                   league  ...  red_card_y  rating_y  accuratePass_y  \
# 0       First Division A  ...         0.0  6.221053        7.315789
# 1                 LaLiga  ...         0.0  6.475000        1.500000
# 2                Serie A  ...         1.0  6.480952       34.000000
# 3  Liga Portugal Betclic  ...         0.0  6.600000       10.500000
# 4                 LaLiga  ...         0.0  6.661538       28.846154
#
#    accurateLongBalls_y  accurateCross_y  accurateKeeperSweeper_y  \
# 0             0.473684         0.052632                      0.0
# 1             0.250000         0.000000                      0.0
# 2             1.380952         0.190476                      0.0
# 3             0.500000         0.000000                      0.0
# 4             0.769231         0.000000                      0.0
#
#    expectedAssists_y  expectedGoals_y  xGChain_y  xGBuildup_y
# 0           0.020446         0.003842   0.034001     0.030454
# 1           0.001620         0.005375   0.003246     0.000000
# 2           0.037272         0.008829   0.121839     0.095601
# 3           0.003336         0.000000   0.000000     0.000000
# 4           0.003302         0.016800   0.000000     0.000000
#
# [5 rows x 103 columns]

# %%
# Base Line linear model with all of the features:
linReg = blm.Simple_Linear_Regression(train)
linReg.perform_CV()
# Out:
# MSE for train: mean: 13661786547569.37 std: 404484151541.2856
# MSE for test:  mean: 14648068873212.0  std: 3782715533129.2026
#
# RMSE for train: mean: 3695780.464906578 std: 54711.08465649266
# RMSE for test: mean: 3794112.0730202748 std: 502774.75132885517
#
# R^2 for train: mean: 0.8804914017516285 std: 0.00305339310351729
# R^2 for test: mean: 0.867764095678982 std: 0.029030771697393872
#
# MAE for train: mean: 2010425.8606619413 std: 27746.2258961103
# MAE for test: mean: 2060110.4340272516 std: 102230.07711590621
#
# MAPE for train: mean: 1.4143744413536832 std: 0.025182026474606555
# MAPE for test: mean: 1.4371414240851705 std: 0.08284082509841267

# %%
players = ['bukayo saka','declan rice','jude bellingham','harry kane','cole palmer','martin degaard','cody gakpo',
           'gabriel jesus',]
for p in players:
    pred = linReg.predict_player(train,player=p)
    true = train[train['name'] == p].target_adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 122133267.739669 vs actual [140000000]
#
# player "declan rice" has prediction 95221889.776699 vs actual [120000000]
#
# player "jude bellingham" has prediction 141256397.035459 vs actual [180000000]
#
# player "harry kane" has prediction 103966294.569530 vs actual [100000000]
#
# player "cole palmer" has prediction 58987762.211771 vs actual [90000000]
#
# player "martin degaard" has prediction 81118806.262563 vs actual [110000000]
#
# player "cody gakpo" has prediction 47264878.290280 vs actual [55000000]
#
# player "gabriel jesus" has prediction 57592861.135028 vs actual [55000000]

# %%
linReg.evaluate(test)
# Out:
# MSE for train: 13709864860371.408
# MSE for test:  14463280193445.855
#
# RMSE for train: 3702683.467482929
# RMSE for test: 3803061.9497249653
#
# R^2 for train: 0.8801292332972934
# R^2 for test: 0.9122389929317465
#
# MAE for train: 2009123.118636529
# MAE for test: 2062125.6325010608
#
# MAPE for train: 14.745585258942523
# MAPE for test: 2.2034033378463014

# %%
log_linReg = blm.log_scale_Linear_Regression(train)
log_linReg.perform_CV()
# Out:
# MSE for train: mean: 0.27310453152888964 std: 0.0017504576661957411
# MSE for test:  mean: 0.28226399179732187  std: 0.016155561358109312
#
# RMSE for train: mean: 0.5225913576100568 std: 0.0016746582240234366
# RMSE for test: mean: 0.5310667244061926 std: 0.015235682649583943
#
# R^2 for train: mean: 0.8560875657774476 std: 0.0012282380340246624
# R^2 for test: mean: 0.8507990723708936 std: 0.01103265776929989
#
# MAE for train: mean: 0.3779186877880429 std: 0.001279702097645114
# MAE for test: mean: 0.3842574005496693 std: 0.010561406396140508
#
# MAPE for train: mean: 0.026651522703619618 std: 9.006019301644778e-05
# MAPE for test: mean: 0.027084351075523795 std: 0.0007634838285218048

# %%
for p in players:
    pred = log_linReg.predict_player(train,player=p)
    true = train[train['name'] == p].target_adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 403266260.940545 vs actual [140000000]
#
# player "declan rice" has prediction 145415710.306075 vs actual [120000000]
#
# player "jude bellingham" has prediction 361245959.158533 vs actual [180000000]
#
# player "harry kane" has prediction 211325049.936704 vs actual [100000000]
#
# player "cole palmer" has prediction 300024027.075439 vs actual [90000000]
#
# player "martin degaard" has prediction 73312568.914123 vs actual [110000000]
#
# player "cody gakpo" has prediction 40429080.846655 vs actual [55000000]
#
# player "gabriel jesus" has prediction 36288863.619081 vs actual [55000000]

# %%
log_linReg.evaluate(test)
# Out:
# MSE for train: 0.2735540608193281
# MSE for test:  0.2754663162351389
#
# RMSE for train: 0.5230239581695356
# RMSE for test: 0.5248488508467356
#
# R^2 for train: 0.8558564950763686
# R^2 for test: 0.8516509255782095
#
# MAE for train: 0.3781339816067507
# MAE for test: 0.3881908037786304
#
# MAPE for train: 0.02665036056686692
# MAPE for test: 0.027299419326625073

# %%
quadReg = blm.Poly_Linear_Regression(train,quad_f=['age'],cubic_f=[])
quadReg.perform_CV()
# Out:
# MSE for train: mean: 13348095587048.059 std: 394597551209.8318
# MSE for test:  mean: 14325104806989.506  std: 3690472247605.3813
#
# RMSE for train: mean: 3653105.283846454 std: 54012.70388688223
# RMSE for test: mean: 3752376.5465383106 std: 494747.4709169622
#
# R^2 for train: mean: 0.8832328348391204 std: 0.0030804719566008927
# R^2 for test: mean: 0.870476152873033 std: 0.02916514673475643
#
# MAE for train: mean: 2023893.9955501533 std: 28008.101333439787
# MAE for test: mean: 2073724.042570083 std: 101575.78335222234
#
# MAPE for train: mean: 1.4485245011352104 std: 0.02497700980987843
# MAPE for test: mean: 1.4702310773555742 std: 0.0651370339292396

# %%
for p in players:
    pred = quadReg.predict_player(train,player=p)
    true = train[train['name'] == p].target_adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "bukayo saka" has prediction None vs actual [140000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "declan rice" has prediction None vs actual [120000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "jude bellingham" has prediction None vs actual [180000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "harry kane" has prediction None vs actual [100000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "cole palmer" has prediction None vs actual [90000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "martin degaard" has prediction None vs actual [110000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "cody gakpo" has prediction None vs actual [55000000]
#
# The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.
#
# player "gabriel jesus" has prediction None vs actual [55000000]

# %%
pcaReg = blm.PCA_Linear_Regression(train)
pcaReg.perform_CV()
# Out:
# MSE for train: mean: 13661779467481.633 std: 404487374969.5732
# MSE for test:  mean: 14648043261957.496  std: 3782658037618.828
#
# RMSE for train: mean: 3695779.500281083 std: 54711.541595363495
# RMSE for test: mean: 3794109.4416985353 std: 502769.138244905
#
# R^2 for train: mean: 0.8804914628925748 std: 0.0030534563792792343
# R^2 for test: mean: 0.8677644399947388 std: 0.029029467680600645
#
# MAE for train: mean: 2010427.9904116255 std: 27741.154158524223
# MAE for test: mean: 2060118.6020263836 std: 102241.05405351098
#
# MAPE for train: mean: 1.4143662293079087 std: 0.0251815959081972
# MAPE for test: mean: 1.437135926296222 std: 0.08285426233095626

# %%
for p in players:
    pred = pcaReg.predict_player(train,player=p)
    true = train[train['name'] == p].target_adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 122132764.881482 vs actual [140000000]
#
# player "declan rice" has prediction 95220854.363906 vs actual [120000000]
#
# player "jude bellingham" has prediction 141256823.753066 vs actual [180000000]
#
# player "harry kane" has prediction 103965050.748417 vs actual [100000000]
#
# player "cole palmer" has prediction 58987727.047579 vs actual [90000000]
#
# player "martin degaard" has prediction 81119121.781149 vs actual [110000000]
#
# player "cody gakpo" has prediction 47264275.164930 vs actual [55000000]
#
# player "gabriel jesus" has prediction 57592480.987600 vs actual [55000000]

# %%
pcaReg.evaluate(test)
# Out:
# MSE for train: 13709858665106.346
# MSE for test:  14463169272892.746
#
# RMSE for train: 3702682.6308916006
# RMSE for test: 3803047.366638068
#
# R^2 for train: 0.8801292874649442
# R^2 for test: 0.912239665980966
#
# MAE for train: 2009133.4310254748
# MAE for test: 2062113.9754057012
#
# MAPE for train: 32.915150393915546
# MAPE for test: 2.26555541013584

# %%
dtReg = blm.Tree_Reg(train,type='RFR')
dtReg.perform_CV()
# Out:
# MSE for train: mean: 1852098361059.3152 std: 71414071129.342
# MSE for test:  mean: 13355802268876.89  std: 5350856177675.166
#
# RMSE for train: mean: 1360659.7434328306 std: 26522.135295262233
# RMSE for test: mean: 3590179.9186108084 std: 682942.4725996925
#
# R^2 for train: mean: 0.983804108387479 std: 0.00039989716305391
# R^2 for test: mean: 0.8828063294253624 std: 0.027063959255546152
#
# MAE for train: mean: 562865.1445398584 std: 4287.369829544347
# MAE for test: mean: 1519037.6241320404 std: 130008.78113451673
#
# MAPE for train: mean: 0.2193879266331463 std: 0.0017960570262709203
# MAPE for test: mean: 0.5965095598053904 std: 0.06379705140206055

# %%
for p in players:
    pred = dtReg.predict_player(train,player=p)
    true = train[train['name'] == p].target_adjusted_market_value.values
    print(f'player "{p}" has prediction {pred} vs actual {true}\n')
# Out:
# player "bukayo saka" has prediction 135200000.000000 vs actual [140000000]
#
# player "declan rice" has prediction 114000000.000000 vs actual [120000000]
#
# player "jude bellingham" has prediction 158150000.000000 vs actual [180000000]
#
# player "harry kane" has prediction 116150000.000000 vs actual [100000000]
#
# player "cole palmer" has prediction 70804111.370000 vs actual [90000000]
#
# player "martin degaard" has prediction 104740405.600000 vs actual [110000000]
#
# player "cody gakpo" has prediction 52320000.000000 vs actual [55000000]
#
# player "gabriel jesus" has prediction 55388660.200000 vs actual [55000000]

# %%
dtReg.evaluate(test)
# Out:
# MSE for train: 1848073077090.5544
# MSE for test:  18326113467796.15
#
# RMSE for train: 1359438.5153770489
# RMSE for test: 4280901.011212026
#
# R^2 for train: 0.9825568338270533
# R^2 for test: 0.8514259392379904
#
# MAE for train: 562637.2203444564
# MAE for test: 1565557.0835793358
#
# MAPE for train: 0.1459654778514774
# MAPE for test: 0.37778248975373296
