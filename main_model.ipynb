# %%
import pandas as pd
import models.main_model.main_model as mm
pd.set_option('display.float_format','{:.2f}'.format)


data = pd.concat([pd.read_csv('data/main_data/train/train.csv'),pd.read_csv('data/main_data/test/test.csv')])

# %%
model = mm.main_model()

data['prediction'] = model.predict_scaled(data)
data
# Out:
#                        name         dob pos  height   foot        date  \
# 0               noah mbamba  2005-01-04   D  187.00  right  2024-02-03
# 1            zachary duncan  2000-05-29   M  183.00  right  2021-11-07
# 2              manuel neuer  1986-03-26   G  193.00  right  2024-10-19
# 3             mickel miller  1995-12-01   M  173.00   left  2024-04-12
# 4        gaetano monachello  1994-03-02   F  185.00   left  2016-05-15
# ...                     ...         ...  ..     ...    ...         ...
# 2337         arbnor mucolli  1999-09-14   F  175.00   left  2022-05-21
# 2338         victor nelsson  1998-10-13   D  187.00  right  2021-08-08
# 2339            elves balde  1999-10-01   M  168.00  right  2024-10-06
# 2340   stephen duke-mckenna  2000-08-16   M  170.00  right  2023-10-07
# 2341  athanasios karagounis  1991-09-24   F  179.00   both  2017-11-05
#
#       market_value  adjusted_market_value                 team  \
# ...
